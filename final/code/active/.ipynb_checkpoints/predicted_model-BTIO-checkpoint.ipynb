# %%
# Data manipulation
import pandas as pd
import numpy as np
# Evaluation of the model
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 18
# %matplotlib inline
MAX_EVALS = 100
import csv
from hyperopt import STATUS_OK
from timeit import default_timer as timer
import json
import shlex
import subprocess
import logging
from pprint import pprint
import re
import os

# %%
file_suffix = "temp" + str(MAX_EVALS)
def runthebenchmark(hyperparameters):
    os.chdir('/home/meghaagr/project/progress/active/../')
    storeinfile(hyperparameters)
    out=subprocess.Popen(["python3","read_config_general.py","-n 8","-c200 200 400 4 4 4 1"], shell=False, stdout=subprocess.PIPE)
    logging.basicConfig(level=logging.DEBUG)
    output=out.stdout.read().decode('utf-8')
    print("output"+output)
    if len(output.split(" ")) > 5:
        values = output.split(" ")
        value = float(float(values[6])*1024)/float(values[5]) + float(float(values[3])*1024)/float(values[2])
        value = float(value)
        print(value)
        return float((value/100)**3),output
    return 0,0

# %%
import json
from sklearn.externals import joblib
import os
os.chdir('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active')


# Loading the model and scaler
filename="finalxgb.sav"
loaded_model = joblib.load(open(filename, 'rb'))
scaler_filename = "scalerxgb.save"
scaler = joblib.load(scaler_filename)

# %%
def runfromsavedmodel(hyperparameters):
### INITIALIZE THIS MANUALLY ####
    nx_g = 300
    ny_g = 300
    nz_g = 480
    npx  = 5
    npy  = 4 
    npz  = 8
   # Active learning model choosees and saves the values of parameters
    storeinfile(hyperparameters)
    with open('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json') as f:
        data = json.load(f)

    romio_ds_read = data["mpi"]["romio_ds_read"] == "enable"
    romio_ds_write = data["mpi"]["romio_ds_write"] == "enable"
    cb_buffer_size = data["mpi"]["cb_buffer_size"]
    stripe_size = data["lfs"]["setstripe"]["size"]
    stripe_count = data["lfs"]["setstripe"]["count"]
    col_names =  ['cb5','cb6','cb7','cb8','cb8','cb10','cb11','cb12']
    cb_df  = pd.DataFrame(columns = col_names)
    cb_df.loc[len(cb_df)] = [romio_ds_read, romio_ds_write, stripe_size, stripe_count, cb_buffer_size,str(nx_g/npx),str(ny_g/npy),str(nz_g/npz)]


    col_names =  ['0','1', '2','3','4','5']
    my_df = pd.DataFrame(columns=col_names)
    

    my_df.loc[len(my_df)] = [nx_g,ny_g,nz_g,npx,npy,npz]
    x = pd.concat([my_df,cb_df], axis=1)
    #normalize the test data
    norm_df = pd.DataFrame(scaler.transform(x))
    out = loaded_model.predict(norm_df)
    return float(1/float(out[0])),0

# %%
# # Import section
# import pickle
# import json
# from sklearn.externals import joblib
# import os
# os.chdir('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active')


# # Loading the model and scaler
# filename="final.sav"
# loaded_model = pickle.load(open(filename, 'rb'))
# scaler_filename = "scaler.save"
# scaler = joblib.load(scaler_filename)

# %%
# def runfromsavedmodel(hyperparameters):
#    # Active learning model choosees and saves the values of parameters
#     storeinfile(hyperparameters)
#     with open('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json') as f:
#         data = json.load(f)

#     cb_buffer_size = data["mpi"]["cb_buffer_size"]
#     stripe_size = data["lfs"]["setstripe"]["size"]
#     stripe_count = data["lfs"]["setstripe"]["count"]
#     col_names =  ['cb1', 'cb2', 'cb3']
#     cb_df  = pd.DataFrame(columns = col_names)
#     cb_df.loc[len(cb_df)] = [stripe_size, stripe_count, cb_buffer_size]

#     #normalize the test data
#     norm_df = scaler.transform( cb_df )
#     temp = pd.DataFrame(norm_df)

#     col_names =  ['0','1', '2','3','4','5']
#     my_df = pd.DataFrame(columns=col_names)
    
#     ### INITIALIZE THIS MANUALLY ####
#     my_df.loc[len(my_df)] = [300,300,300,2,2,4]
#     x = pd.concat([my_df,temp], axis=1)
#     out = loaded_model.predict(x)
#     return float(1/float(out[0])),0

# %%
def storeinfile(hyperparameters):
    data={"mpi": {"romio_ds_read": "enable", "romio_ds_write": "disable"}, "lfs": {"setstripe": {"size": "16777216", "count": 4}}}
    data["lfs"]["setstripe"]["size"] = int(hyperparameters["setstripe-size"])
    data["lfs"]["setstripe"]["count"] = int(hyperparameters["setstripe-count"])

    data["mpi"]["romio_ds_read"] = hyperparameters["romio_ds_read"]
    data["mpi"]["romio_ds_write"] = hyperparameters["romio_ds_write"]
    data["mpi"]["romio_cb_read"] = hyperparameters["romio_cb_read"]
    data["mpi"]["romio_cb_write"] = hyperparameters["romio_cb_write"]
    data["mpi"]["cb_buffer_size"] = str(int(hyperparameters["cb_buffer_size"]))
    with open("/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json","w") as fp:
        json.dump(data,fp)
    print(data)

# %%
def objective(hyperparameters):
    global ITERATION
    ITERATION += 1
    start = timer()
    result=0
    while(result == 0):
        print("rerun")
        result,output = runfromsavedmodel(hyperparameters)
        print(result)
    run_time = timer() - start
    print({'loss': result, 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK})
    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([float(result), hyperparameters, ITERATION, run_time, output])
    return {'loss': float(result), 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK}

# %%
from hyperopt import hp
from hyperopt.pyll.stochastic import sample

space = {
    'romio_ds_read' : hp.choice('romio_ds_read',['enable','disable']),
    'romio_ds_write' : hp.choice('romio_ds_write',['enable','disable']),
    'romio_cb_read' : hp.choice('romio_cb_read',['enable','disable']),
    'romio_cb_write' : hp.choice('romio_cb_write',['enable','disable']),
    'cb_buffer_size' : 1048576*hp.quniform('cb_buffer_size',1,512,1),
    'setstripe-size' : 65536*(hp.quniform('setstripe-size',0,512,1)),
    'setstripe-count' : hp.qloguniform('setstripe-count',0,5,1)
    
}

# %%
x = sample(space)
params = x
print(x)

cb_buffer_size_dist = []
for _ in range(1000):
    cb_buffer_size_dist.append(sample(space)['cb_buffer_size'])
    
setstripe_size_dist = []
for _ in range(1000):
    setstripe_size_dist.append(sample(space)['setstripe-size'])
    
setstripe_count_dist = []
for _ in range(1000):
    setstripe_count_dist.append(sample(space)['setstripe-count']) 
    
romio_ds_read_dist = []
for _ in range(20):
    romio_ds_read_dist.append(sample(space)['romio_ds_read'])
    
romio_ds_write_dist = []
for _ in range(20):
    romio_ds_write_dist.append(sample(space)['romio_ds_write'])
    
romio_cb_read_dist = []
for _ in range(20):
    romio_cb_read_dist.append(sample(space)['romio_cb_read']) 
    
romio_cb_write_dist = []
for _ in range(20):
    romio_cb_write_dist.append(sample(space)['romio_cb_write'])
# Out:
# {'cb_buffer_size': 444596224.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 27.0, 'setstripe-size': 30277632.0}

# %%
# File to save first results
print(os.getcwd())
out_file = '/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/result/gbm_trials-'+file_suffix+'.csv'

of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
writer.writerow(['loss', 'params', 'iteration', 'train_time', 'output'])
of_connection.close()
# Out:
# /home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active

# %%
from hyperopt import tpe

# Create the algorithm
tpe_algorithm = tpe.suggest


from hyperopt import Trials

# Record results
bayes_trials = Trials()

from hyperopt import fmin


ITERATION = 1

best = fmin(fn = objective, space = space, algo = tpe.suggest, trials = bayes_trials, max_evals = MAX_EVALS)
# Out:
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '466616320'}, 'lfs': {'setstripe': {'size': 15466496, 'count': 5}}}
# 0.0013036814758590957
# {'loss': 0.0013036814758590957, 'hyperparameters': {'cb_buffer_size': 466616320.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 5.0, 'setstripe-size': 15466496.0}, 'iteration': 2, 'iteration_time': 0.03562995399988722, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '53477376'}, 'lfs': {'setstripe': {'size': 24051712, 'count': 88}}}
# 0.0013798653856422244
# {'loss': 0.0013798653856422244, 'hyperparameters': {'cb_buffer_size': 53477376.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 88.0, 'setstripe-size': 24051712.0}, 'iteration': 3, 'iteration_time': 0.038080482000623306, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '313524224'}, 'lfs': {'setstripe': {'size': 27459584, 'count': 16}}}
# 0.001139482728810761
# {'loss': 0.001139482728810761, 'hyperparameters': {'cb_buffer_size': 313524224.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 16.0, 'setstripe-size': 27459584.0}, 'iteration': 4, 'iteration_time': 0.06648421799945936, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '328204288'}, 'lfs': {'setstripe': {'size': 1507328, 'count': 93}}}
# 0.0014943373607050748
# {'loss': 0.0014943373607050748, 'hyperparameters': {'cb_buffer_size': 328204288.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 93.0, 'setstripe-size': 1507328.0}, 'iteration': 5, 'iteration_time': 0.04694107599971176, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '287309824'}, 'lfs': {'setstripe': {'size': 7471104, 'count': 34}}}
# 0.001405022285776765
# {'loss': 0.001405022285776765, 'hyperparameters': {'cb_buffer_size': 287309824.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 34.0, 'setstripe-size': 7471104.0}, 'iteration': 6, 'iteration_time': 0.03413322500000504, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '229638144'}, 'lfs': {'setstripe': {'size': 26869760, 'count': 71}}}
# 0.0012529012149639412
# {'loss': 0.0012529012149639412, 'hyperparameters': {'cb_buffer_size': 229638144.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 71.0, 'setstripe-size': 26869760.0}, 'iteration': 7, 'iteration_time': 0.0278386979998686, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '93323264'}, 'lfs': {'setstripe': {'size': 10092544, 'count': 50}}}
# 0.0013789885374944492
# {'loss': 0.0013789885374944492, 'hyperparameters': {'cb_buffer_size': 93323264.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 50.0, 'setstripe-size': 10092544.0}, 'iteration': 8, 'iteration_time': 0.037595477000650135, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '389021696'}, 'lfs': {'setstripe': {'size': 28114944, 'count': 2}}}
# 0.0015221711229161544
# {'loss': 0.0015221711229161544, 'hyperparameters': {'cb_buffer_size': 389021696.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 28114944.0}, 'iteration': 9, 'iteration_time': 0.03821318500013149, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '523239424'}, 'lfs': {'setstripe': {'size': 21626880, 'count': 7}}}
# 0.0012687868975449935
# {'loss': 0.0012687868975449935, 'hyperparameters': {'cb_buffer_size': 523239424.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 21626880.0}, 'iteration': 10, 'iteration_time': 0.04842325299978256, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '489684992'}, 'lfs': {'setstripe': {'size': 19726336, 'count': 120}}}
# 0.0011746605697691666
# {'loss': 0.0011746605697691666, 'hyperparameters': {'cb_buffer_size': 489684992.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 120.0, 'setstripe-size': 19726336.0}, 'iteration': 11, 'iteration_time': 0.033074675000534626, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '139460608'}, 'lfs': {'setstripe': {'size': 15400960, 'count': 28}}}
# 0.0013052074303139206
# {'loss': 0.0013052074303139206, 'hyperparameters': {'cb_buffer_size': 139460608.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 28.0, 'setstripe-size': 15400960.0}, 'iteration': 12, 'iteration_time': 0.03707901199959451, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '369098752'}, 'lfs': {'setstripe': {'size': 23724032, 'count': 15}}}
# 0.0011698713291484824
# {'loss': 0.0011698713291484824, 'hyperparameters': {'cb_buffer_size': 369098752.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 15.0, 'setstripe-size': 23724032.0}, 'iteration': 13, 'iteration_time': 0.03732529599983536, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '209715200'}, 'lfs': {'setstripe': {'size': 17104896, 'count': 2}}}
# 0.0015369379644221
# {'loss': 0.0015369379644221, 'hyperparameters': {'cb_buffer_size': 209715200.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 2.0, 'setstripe-size': 17104896.0}, 'iteration': 14, 'iteration_time': 0.05938171300022077, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '159383552'}, 'lfs': {'setstripe': {'size': 2424832, 'count': 4}}}
# 0.0014407891415995678
# {'loss': 0.0014407891415995678, 'hyperparameters': {'cb_buffer_size': 159383552.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 4.0, 'setstripe-size': 2424832.0}, 'iteration': 15, 'iteration_time': 0.05591552999976557, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '499122176'}, 'lfs': {'setstripe': {'size': 13762560, 'count': 3}}}
# 0.0013608700198856135
# {'loss': 0.0013608700198856135, 'hyperparameters': {'cb_buffer_size': 499122176.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 3.0, 'setstripe-size': 13762560.0}, 'iteration': 16, 'iteration_time': 0.04135084100016684, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '430964736'}, 'lfs': {'setstripe': {'size': 7733248, 'count': 15}}}
# 0.0012808696905062648
# {'loss': 0.0012808696905062648, 'hyperparameters': {'cb_buffer_size': 430964736.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 15.0, 'setstripe-size': 7733248.0}, 'iteration': 17, 'iteration_time': 0.03653064899935998, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '477102080'}, 'lfs': {'setstripe': {'size': 1507328, 'count': 3}}}
# 0.0013909170501861785
# {'loss': 0.0013909170501861785, 'hyperparameters': {'cb_buffer_size': 477102080.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 3.0, 'setstripe-size': 1507328.0}, 'iteration': 18, 'iteration_time': 0.03260574599971733, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '513802240'}, 'lfs': {'setstripe': {'size': 15794176, 'count': 3}}}
# 0.001355279867277866
# {'loss': 0.001355279867277866, 'hyperparameters': {'cb_buffer_size': 513802240.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 3.0, 'setstripe-size': 15794176.0}, 'iteration': 19, 'iteration_time': 0.035159361000296485, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '13631488'}, 'lfs': {'setstripe': {'size': 30801920, 'count': 6}}}
# 0.0016330444307892267
# {'loss': 0.0016330444307892267, 'hyperparameters': {'cb_buffer_size': 13631488.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 6.0, 'setstripe-size': 30801920.0}, 'iteration': 20, 'iteration_time': 0.030171583999617724, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '38797312'}, 'lfs': {'setstripe': {'size': 23396352, 'count': 4}}}
# 0.0016914447213276684
# {'loss': 0.0016914447213276684, 'hyperparameters': {'cb_buffer_size': 38797312.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 4.0, 'setstripe-size': 23396352.0}, 'iteration': 21, 'iteration_time': 0.04613372400035587, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '361758720'}, 'lfs': {'setstripe': {'size': 31260672, 'count': 12}}}
# 0.0011975937604663364
# {'loss': 0.0011975937604663364, 'hyperparameters': {'cb_buffer_size': 361758720.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 12.0, 'setstripe-size': 31260672.0}, 'iteration': 22, 'iteration_time': 0.06783164199987368, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '295698432'}, 'lfs': {'setstripe': {'size': 27787264, 'count': 15}}}
# 0.001139482728810761
# {'loss': 0.001139482728810761, 'hyperparameters': {'cb_buffer_size': 295698432.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 15.0, 'setstripe-size': 27787264.0}, 'iteration': 23, 'iteration_time': 0.07318423600008828, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '279969792'}, 'lfs': {'setstripe': {'size': 32768000, 'count': 10}}}
# 0.0012336980588758002
# {'loss': 0.0012336980588758002, 'hyperparameters': {'cb_buffer_size': 279969792.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 10.0, 'setstripe-size': 32768000.0}, 'iteration': 24, 'iteration_time': 0.06073909499991714, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '217055232'}, 'lfs': {'setstripe': {'size': 27131904, 'count': 25}}}
# 0.0012248988807994857
# {'loss': 0.0012248988807994857, 'hyperparameters': {'cb_buffer_size': 217055232.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 25.0, 'setstripe-size': 27131904.0}, 'iteration': 25, 'iteration_time': 0.038801854000666935, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '317718528'}, 'lfs': {'setstripe': {'size': 33226752, 'count': 19}}}
# 0.0011514899439309296
# {'loss': 0.0011514899439309296, 'hyperparameters': {'cb_buffer_size': 317718528.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 19.0, 'setstripe-size': 33226752.0}, 'iteration': 26, 'iteration_time': 0.034335310000642494, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '413138944'}, 'lfs': {'setstripe': {'size': 29229056, 'count': 9}}}
# 0.0012485892024163981
# {'loss': 0.0012485892024163981, 'hyperparameters': {'cb_buffer_size': 413138944.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 9.0, 'setstripe-size': 29229056.0}, 'iteration': 27, 'iteration_time': 0.02492122900002869, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '326107136'}, 'lfs': {'setstripe': {'size': 19791872, 'count': 51}}}
# 0.0012247279327147152
# {'loss': 0.0012247279327147152, 'hyperparameters': {'cb_buffer_size': 326107136.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 51.0, 'setstripe-size': 19791872.0}, 'iteration': 28, 'iteration_time': 0.03382090900049661, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '250609664'}, 'lfs': {'setstripe': {'size': 25755648, 'count': 39}}}
# 0.0012529012149639412
# {'loss': 0.0012529012149639412, 'hyperparameters': {'cb_buffer_size': 250609664.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 39.0, 'setstripe-size': 25755648.0}, 'iteration': 29, 'iteration_time': 0.03487745599977643, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '158334976'}, 'lfs': {'setstripe': {'size': 29818880, 'count': 1}}}
# 0.0022163143952352487
# {'loss': 0.0022163143952352487, 'hyperparameters': {'cb_buffer_size': 158334976.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 1.0, 'setstripe-size': 29818880.0}, 'iteration': 30, 'iteration_time': 0.038588117000472266, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '188743680'}, 'lfs': {'setstripe': {'size': 19267584, 'count': 19}}}
# 0.001242074892779689
# {'loss': 0.001242074892779689, 'hyperparameters': {'cb_buffer_size': 188743680.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 19.0, 'setstripe-size': 19267584.0}, 'iteration': 31, 'iteration_time': 0.024927660000685137, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '113246208'}, 'lfs': {'setstripe': {'size': 25559040, 'count': 7}}}
# 0.0013935512361855857
# {'loss': 0.0013935512361855857, 'hyperparameters': {'cb_buffer_size': 113246208.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 7.0, 'setstripe-size': 25559040.0}, 'iteration': 32, 'iteration_time': 0.03663727100047254, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '301989888'}, 'lfs': {'setstripe': {'size': 33488896, 'count': 23}}}
# 0.001145769920812221
# {'loss': 0.001145769920812221, 'hyperparameters': {'cb_buffer_size': 301989888.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 23.0, 'setstripe-size': 33488896.0}, 'iteration': 33, 'iteration_time': 0.03849855699991167, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '435159040'}, 'lfs': {'setstripe': {'size': 24707072, 'count': 53}}}
# 0.0011680936197377592
# {'loss': 0.0011680936197377592, 'hyperparameters': {'cb_buffer_size': 435159040.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 53.0, 'setstripe-size': 24707072.0}, 'iteration': 34, 'iteration_time': 0.02728291800031002, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '253755392'}, 'lfs': {'setstripe': {'size': 22413312, 'count': 36}}}
# 0.0012950041405512635
# {'loss': 0.0012950041405512635, 'hyperparameters': {'cb_buffer_size': 253755392.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 36.0, 'setstripe-size': 22413312.0}, 'iteration': 35, 'iteration_time': 0.054941559999861056, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '341835776'}, 'lfs': {'setstripe': {'size': 11337728, 'count': 79}}}
# 0.001338296509622396
# {'loss': 0.001338296509622396, 'hyperparameters': {'cb_buffer_size': 341835776.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 79.0, 'setstripe-size': 11337728.0}, 'iteration': 36, 'iteration_time': 0.05393284300043888, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '287309824'}, 'lfs': {'setstripe': {'size': 28049408, 'count': 11}}}
# 0.0012210239698988974
# {'loss': 0.0012210239698988974, 'hyperparameters': {'cb_buffer_size': 287309824.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 11.0, 'setstripe-size': 28049408.0}, 'iteration': 37, 'iteration_time': 0.06241722800041316, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '396361728'}, 'lfs': {'setstripe': {'size': 21299200, 'count': 1}}}
# 0.002237709974813471
# {'loss': 0.002237709974813471, 'hyperparameters': {'cb_buffer_size': 396361728.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 1.0, 'setstripe-size': 21299200.0}, 'iteration': 38, 'iteration_time': 0.04735959899971931, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '450887680'}, 'lfs': {'setstripe': {'size': 31260672, 'count': 145}}}
# 0.0011450844503276636
# {'loss': 0.0011450844503276636, 'hyperparameters': {'cb_buffer_size': 450887680.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 145.0, 'setstripe-size': 31260672.0}, 'iteration': 39, 'iteration_time': 0.040986150000208, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '77594624'}, 'lfs': {'setstripe': {'size': 18087936, 'count': 8}}}
# 0.0013304882885522462
# {'loss': 0.0013304882885522462, 'hyperparameters': {'cb_buffer_size': 77594624.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 8.0, 'setstripe-size': 18087936.0}, 'iteration': 40, 'iteration_time': 0.03966875400055869, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '189792256'}, 'lfs': {'setstripe': {'size': 12845056, 'count': 15}}}
# 0.001231551810153402
# {'loss': 0.001231551810153402, 'hyperparameters': {'cb_buffer_size': 189792256.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 15.0, 'setstripe-size': 12845056.0}, 'iteration': 41, 'iteration_time': 0.04256815799999458, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '247463936'}, 'lfs': {'setstripe': {'size': 26411008, 'count': 103}}}
# 0.0012529012149639412
# {'loss': 0.0012529012149639412, 'hyperparameters': {'cb_buffer_size': 247463936.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 103.0, 'setstripe-size': 26411008.0}, 'iteration': 42, 'iteration_time': 0.05602886800079432, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '357564416'}, 'lfs': {'setstripe': {'size': 28770304, 'count': 30}}}
# 0.0011322347808786389
# {'loss': 0.0011322347808786389, 'hyperparameters': {'cb_buffer_size': 357564416.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 30.0, 'setstripe-size': 28770304.0}, 'iteration': 43, 'iteration_time': 0.039934960000209685, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '364904448'}, 'lfs': {'setstripe': {'size': 3473408, 'count': 62}}}
# 0.001348329216501726
# {'loss': 0.001348329216501726, 'hyperparameters': {'cb_buffer_size': 364904448.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 62.0, 'setstripe-size': 3473408.0}, 'iteration': 44, 'iteration_time': 0.0446732090003934, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '392167424'}, 'lfs': {'setstripe': {'size': 29622272, 'count': 30}}}
# 0.0011322347808786389
# {'loss': 0.0011322347808786389, 'hyperparameters': {'cb_buffer_size': 392167424.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 30.0, 'setstripe-size': 29622272.0}, 'iteration': 45, 'iteration_time': 0.03411136399972747, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '457179136'}, 'lfs': {'setstripe': {'size': 32047104, 'count': 31}}}
# 0.0011838245234481288
# {'loss': 0.0011838245234481288, 'hyperparameters': {'cb_buffer_size': 457179136.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 31.0, 'setstripe-size': 32047104.0}, 'iteration': 46, 'iteration_time': 0.042482576000111294, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '529530880'}, 'lfs': {'setstripe': {'size': 29163520, 'count': 39}}}
# 0.0011196605810180082
# {'loss': 0.0011196605810180082, 'hyperparameters': {'cb_buffer_size': 529530880.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 39.0, 'setstripe-size': 29163520.0}, 'iteration': 47, 'iteration_time': 0.036534232999656524, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '525336576'}, 'lfs': {'setstripe': {'size': 6946816, 'count': 147}}}
# 0.0012787389436183364
# {'loss': 0.0012787389436183364, 'hyperparameters': {'cb_buffer_size': 525336576.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 147.0, 'setstripe-size': 6946816.0}, 'iteration': 48, 'iteration_time': 0.052059640000152285, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '495976448'}, 'lfs': {'setstripe': {'size': 22216704, 'count': 42}}}
# 0.0012215970666758327
# {'loss': 0.0012215970666758327, 'hyperparameters': {'cb_buffer_size': 495976448.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 42.0, 'setstripe-size': 22216704.0}, 'iteration': 49, 'iteration_time': 0.07433193099950586, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '534773760'}, 'lfs': {'setstripe': {'size': 30146560, 'count': 67}}}
# 0.0010657683266585124
# {'loss': 0.0010657683266585124, 'hyperparameters': {'cb_buffer_size': 534773760.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 67.0, 'setstripe-size': 30146560.0}, 'iteration': 50, 'iteration_time': 0.0522366149998561, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '479199232'}, 'lfs': {'setstripe': {'size': 24379392, 'count': 110}}}
# 0.0011680936197377592
# {'loss': 0.0011680936197377592, 'hyperparameters': {'cb_buffer_size': 479199232.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 110.0, 'setstripe-size': 24379392.0}, 'iteration': 51, 'iteration_time': 0.033958156000153394, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '521142272'}, 'lfs': {'setstripe': {'size': 20774912, 'count': 91}}}
# 0.0012247279327147152
# {'loss': 0.0012247279327147152, 'hyperparameters': {'cb_buffer_size': 521142272.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 91.0, 'setstripe-size': 20774912.0}, 'iteration': 52, 'iteration_time': 0.04850508100025763, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '428867584'}, 'lfs': {'setstripe': {'size': 17629184, 'count': 65}}}
# 0.0012247279327147152
# {'loss': 0.0012247279327147152, 'hyperparameters': {'cb_buffer_size': 428867584.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 65.0, 'setstripe-size': 17629184.0}, 'iteration': 53, 'iteration_time': 0.04327949499929673, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '506462208'}, 'lfs': {'setstripe': {'size': 14680064, 'count': 73}}}
# 0.0012667867217184877
# {'loss': 0.0012667867217184877, 'hyperparameters': {'cb_buffer_size': 506462208.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 73.0, 'setstripe-size': 14680064.0}, 'iteration': 54, 'iteration_time': 0.029763346000436286, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '535822336'}, 'lfs': {'setstripe': {'size': 23068672, 'count': 45}}}
# 0.0011222040789488103
# {'loss': 0.0011222040789488103, 'hyperparameters': {'cb_buffer_size': 535822336.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 45.0, 'setstripe-size': 23068672.0}, 'iteration': 55, 'iteration_time': 0.03447604600023624, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '470810624'}, 'lfs': {'setstripe': {'size': 30670848, 'count': 22}}}
# 0.0011243832499836669
# {'loss': 0.0011243832499836669, 'hyperparameters': {'cb_buffer_size': 470810624.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 22.0, 'setstripe-size': 30670848.0}, 'iteration': 56, 'iteration_time': 0.05584799200005364, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '405798912'}, 'lfs': {'setstripe': {'size': 31916032, 'count': 123}}}
# 0.0011700852953901181
# {'loss': 0.0011700852953901181, 'hyperparameters': {'cb_buffer_size': 405798912.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 123.0, 'setstripe-size': 31916032.0}, 'iteration': 57, 'iteration_time': 0.023240610000357265, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '532676608'}, 'lfs': {'setstripe': {'size': 9437184, 'count': 61}}}
# 0.0012620193788991346
# {'loss': 0.0012620193788991346, 'hyperparameters': {'cb_buffer_size': 532676608.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 61.0, 'setstripe-size': 9437184.0}, 'iteration': 58, 'iteration_time': 0.037546534999819414, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '444596224'}, 'lfs': {'setstripe': {'size': 33554432, 'count': 86}}}
# 0.0011243023890327815
# {'loss': 0.0011243023890327815, 'hyperparameters': {'cb_buffer_size': 444596224.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 86.0, 'setstripe-size': 33554432.0}, 'iteration': 59, 'iteration_time': 0.05351337100000819, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '381681664'}, 'lfs': {'setstripe': {'size': 26738688, 'count': 131}}}
# 0.0012129431936296793
# {'loss': 0.0012129431936296793, 'hyperparameters': {'cb_buffer_size': 381681664.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 131.0, 'setstripe-size': 26738688.0}, 'iteration': 60, 'iteration_time': 0.030279354999947827, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '421527552'}, 'lfs': {'setstripe': {'size': 0, 'count': 2}}}
# 0.0015195502042359317
# {'loss': 0.0015195502042359317, 'hyperparameters': {'cb_buffer_size': 421527552.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 0.0}, 'iteration': 61, 'iteration_time': 0.06344293000074686, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '485490688'}, 'lfs': {'setstripe': {'size': 16121856, 'count': 5}}}
# 0.001325146177356872
# {'loss': 0.001325146177356872, 'hyperparameters': {'cb_buffer_size': 485490688.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 5.0, 'setstripe-size': 16121856.0}, 'iteration': 62, 'iteration_time': 0.02474324900049396, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '336592896'}, 'lfs': {'setstripe': {'size': 4784128, 'count': 19}}}
# 0.0013437056077483525
# {'loss': 0.0013437056077483525, 'hyperparameters': {'cb_buffer_size': 336592896.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 19.0, 'setstripe-size': 4784128.0}, 'iteration': 63, 'iteration_time': 0.026773958000376297, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '53477376'}, 'lfs': {'setstripe': {'size': 25296896, 'count': 52}}}
# 0.0013597175863917367
# {'loss': 0.0013597175863917367, 'hyperparameters': {'cb_buffer_size': 53477376.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 52.0, 'setstripe-size': 25296896.0}, 'iteration': 64, 'iteration_time': 0.03323977000036393, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '503316480'}, 'lfs': {'setstripe': {'size': 19136512, 'count': 25}}}
# 0.0011965539188711028
# {'loss': 0.0011965539188711028, 'hyperparameters': {'cb_buffer_size': 503316480.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 25.0, 'setstripe-size': 19136512.0}, 'iteration': 65, 'iteration_time': 0.042449875999409414, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '3145728'}, 'lfs': {'setstripe': {'size': 30015488, 'count': 13}}}
# 0.0017768220803979456
# {'loss': 0.0017768220803979456, 'hyperparameters': {'cb_buffer_size': 3145728.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 13.0, 'setstripe-size': 30015488.0}, 'iteration': 66, 'iteration_time': 0.06002404699938779, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '533725184'}, 'lfs': {'setstripe': {'size': 22937600, 'count': 44}}}
# 0.0011222040789488103
# {'loss': 0.0011222040789488103, 'hyperparameters': {'cb_buffer_size': 533725184.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 44.0, 'setstripe-size': 22937600.0}, 'iteration': 67, 'iteration_time': 0.026894306000031065, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '511705088'}, 'lfs': {'setstripe': {'size': 28639232, 'count': 36}}}
# 0.0010893116546307614
# {'loss': 0.0010893116546307614, 'hyperparameters': {'cb_buffer_size': 511705088.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 36.0, 'setstripe-size': 28639232.0}, 'iteration': 68, 'iteration_time': 0.03016406200003985, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '460324864'}, 'lfs': {'setstripe': {'size': 32505856, 'count': 39}}}
# 0.0011243023890327815
# {'loss': 0.0011243023890327815, 'hyperparameters': {'cb_buffer_size': 460324864.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 39.0, 'setstripe-size': 32505856.0}, 'iteration': 69, 'iteration_time': 0.06923168399953283, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '509607936'}, 'lfs': {'setstripe': {'size': 28180480, 'count': 35}}}
# 0.0010893116546307614
# {'loss': 0.0010893116546307614, 'hyperparameters': {'cb_buffer_size': 509607936.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 35.0, 'setstripe-size': 28180480.0}, 'iteration': 70, 'iteration_time': 0.046347815000444825, 'status': 'ok'}
# rerun
# ...
# 0.0011680936197377592
# {'loss': 0.0011680936197377592, 'hyperparameters': {'cb_buffer_size': 402653184.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 49.0, 'setstripe-size': 24969216.0}, 'iteration': 79, 'iteration_time': 0.03843027099992469, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '276824064'}, 'lfs': {'setstripe': {'size': 28508160, 'count': 111}}}
# 0.0010852886944766596
# {'loss': 0.0010852886944766596, 'hyperparameters': {'cb_buffer_size': 276824064.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 111.0, 'setstripe-size': 28508160.0}, 'iteration': 80, 'iteration_time': 0.03238004699960584, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '120586240'}, 'lfs': {'setstripe': {'size': 33554432, 'count': 131}}}
# 0.0011731902820260934
# {'loss': 0.0011731902820260934, 'hyperparameters': {'cb_buffer_size': 120586240.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 131.0, 'setstripe-size': 33554432.0}, 'iteration': 81, 'iteration_time': 0.03960313199968368, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '262144000'}, 'lfs': {'setstripe': {'size': 31326208, 'count': 106}}}
# 0.001122752926582553
# {'loss': 0.001122752926582553, 'hyperparameters': {'cb_buffer_size': 262144000.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 106.0, 'setstripe-size': 31326208.0}, 'iteration': 82, 'iteration_time': 0.04199362300005305, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '190840832'}, 'lfs': {'setstripe': {'size': 12517376, 'count': 118}}}
# 0.001253278343298212
# {'loss': 0.001253278343298212, 'hyperparameters': {'cb_buffer_size': 190840832.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 118.0, 'setstripe-size': 12517376.0}, 'iteration': 83, 'iteration_time': 0.037421698999423825, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '226492416'}, 'lfs': {'setstripe': {'size': 21430272, 'count': 144}}}
# 0.001212097179654641
# {'loss': 0.001212097179654641, 'hyperparameters': {'cb_buffer_size': 226492416.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 144.0, 'setstripe-size': 21430272.0}, 'iteration': 84, 'iteration_time': 0.05390088600051968, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '161480704'}, 'lfs': {'setstripe': {'size': 23789568, 'count': 57}}}
# 0.0012516904773582607
# {'loss': 0.0012516904773582607, 'hyperparameters': {'cb_buffer_size': 161480704.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 57.0, 'setstripe-size': 23789568.0}, 'iteration': 85, 'iteration_time': 0.050196658999993815, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '39845888'}, 'lfs': {'setstripe': {'size': 32636928, 'count': 85}}}
# 0.0012696526286513265
# {'loss': 0.0012696526286513265, 'hyperparameters': {'cb_buffer_size': 39845888.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 85.0, 'setstripe-size': 32636928.0}, 'iteration': 86, 'iteration_time': 0.026874361000409408, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '322961408'}, 'lfs': {'setstripe': {'size': 30146560, 'count': 69}}}
# 0.0010776678593980215
# {'loss': 0.0010776678593980215, 'hyperparameters': {'cb_buffer_size': 322961408.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 69.0, 'setstripe-size': 30146560.0}, 'iteration': 87, 'iteration_time': 0.02947204900010547, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '312475648'}, 'lfs': {'setstripe': {'size': 30015488, 'count': 68}}}
# 0.0010776678593980215
# {'loss': 0.0010776678593980215, 'hyperparameters': {'cb_buffer_size': 312475648.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 68.0, 'setstripe-size': 30015488.0}, 'iteration': 88, 'iteration_time': 0.02453580499968666, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '309329920'}, 'lfs': {'setstripe': {'size': 26279936, 'count': 22}}}
# 0.001154121582031319
# {'loss': 0.001154121582031319, 'hyperparameters': {'cb_buffer_size': 309329920.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 22.0, 'setstripe-size': 26279936.0}, 'iteration': 89, 'iteration_time': 0.024737296999774117, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '326107136'}, 'lfs': {'setstripe': {'size': 22282240, 'count': 28}}}
# 0.0011459638591927684
# {'loss': 0.0011459638591927684, 'hyperparameters': {'cb_buffer_size': 326107136.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 28.0, 'setstripe-size': 22282240.0}, 'iteration': 90, 'iteration_time': 0.034562622000521515, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '292552704'}, 'lfs': {'setstripe': {'size': 30212096, 'count': 69}}}
# 0.0010776678593980215
# {'loss': 0.0010776678593980215, 'hyperparameters': {'cb_buffer_size': 292552704.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 69.0, 'setstripe-size': 30212096.0}, 'iteration': 91, 'iteration_time': 0.05617170099958457, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '293601280'}, 'lfs': {'setstripe': {'size': 31457280, 'count': 2}}}
# 0.001538555299953958
# {'loss': 0.001538555299953958, 'hyperparameters': {'cb_buffer_size': 293601280.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 2.0, 'setstripe-size': 31457280.0}, 'iteration': 92, 'iteration_time': 0.037484234000658034, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '239075328'}, 'lfs': {'setstripe': {'size': 29425664, 'count': 32}}}
# 0.0011103968564057747
# {'loss': 0.0011103968564057747, 'hyperparameters': {'cb_buffer_size': 239075328.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 32.0, 'setstripe-size': 29425664.0}, 'iteration': 93, 'iteration_time': 0.04003262500009441, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '93323264'}, 'lfs': {'setstripe': {'size': 32833536, 'count': 47}}}
# 0.0011701905109291466
# {'loss': 0.0011701905109291466, 'hyperparameters': {'cb_buffer_size': 93323264.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 47.0, 'setstripe-size': 32833536.0}, 'iteration': 94, 'iteration_time': 0.03436143599992647, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '212860928'}, 'lfs': {'setstripe': {'size': 17039360, 'count': 78}}}
# 0.001212097179654641
# {'loss': 0.001212097179654641, 'hyperparameters': {'cb_buffer_size': 212860928.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 78.0, 'setstripe-size': 17039360.0}, 'iteration': 95, 'iteration_time': 0.04088840100030211, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '352321536'}, 'lfs': {'setstripe': {'size': 27131904, 'count': 8}}}
# 0.0012059496065574687
# {'loss': 0.0012059496065574687, 'hyperparameters': {'cb_buffer_size': 352321536.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 8.0, 'setstripe-size': 27131904.0}, 'iteration': 96, 'iteration_time': 0.05458079800064297, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '174063616'}, 'lfs': {'setstripe': {'size': 15138816, 'count': 27}}}
# 0.001229469384606449
# {'loss': 0.001229469384606449, 'hyperparameters': {'cb_buffer_size': 174063616.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 27.0, 'setstripe-size': 15138816.0}, 'iteration': 97, 'iteration_time': 0.04526061900014611, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '141557760'}, 'lfs': {'setstripe': {'size': 9175040, 'count': 17}}}
# 0.0013764147336527439
# {'loss': 0.0013764147336527439, 'hyperparameters': {'cb_buffer_size': 141557760.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 17.0, 'setstripe-size': 9175040.0}, 'iteration': 98, 'iteration_time': 0.03482953499951691, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '372244480'}, 'lfs': {'setstripe': {'size': 24772608, 'count': 55}}}
# 0.0011680936197377592
# {'loss': 0.0011680936197377592, 'hyperparameters': {'cb_buffer_size': 372244480.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 55.0, 'setstripe-size': 24772608.0}, 'iteration': 99, 'iteration_time': 0.03800573599983181, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '267386880'}, 'lfs': {'setstripe': {'size': 31653888, 'count': 95}}}
# 0.0011684071659358536
# {'loss': 0.0011684071659358536, 'hyperparameters': {'cb_buffer_size': 267386880.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 95.0, 'setstripe-size': 31653888.0}, 'iteration': 100, 'iteration_time': 0.02796652399956656, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '478150656'}, 'lfs': {'setstripe': {'size': 19791872, 'count': 11}}}
# 0.0012199279822544557
# {'loss': 0.0012199279822544557, 'hyperparameters': {'cb_buffer_size': 478150656.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 11.0, 'setstripe-size': 19791872.0}, 'iteration': 101, 'iteration_time': 0.03656164199946943, 'status': 'ok'}
# 100%|██████████| 100/100 [00:07<00:00, 14.22it/s, best loss: 0.0010657683266585124]

# %%
print(best)
d=  best
#print(bayes_trials.results)
bayes_trials_results = sorted(bayes_trials.results, key = lambda x: x['loss'])
#bayes_trials_results[:1]
# Out:
# {'cb_buffer_size': 510.0, 'romio_cb_read': 1, 'romio_cb_write': 1, 'romio_ds_read': 1, 'romio_ds_write': 1, 'setstripe-count': 67.0, 'setstripe-size': 460.0}

# %%
results = pd.read_csv(out_file)

# Sort with best scores on top and reset index for slicing
results.sort_values('train_time', ascending = True, inplace = True)
results.reset_index(inplace = True, drop = True)
results.head()
# Out:
#        loss                                             params  iteration  \
# 0  0.001170  {'cb_buffer_size': 405798912.0, 'romio_cb_read...         57
# 1  0.001078  {'cb_buffer_size': 312475648.0, 'romio_cb_read...         88
# 2  0.001154  {'cb_buffer_size': 309329920.0, 'romio_cb_read...         89
# 3  0.001325  {'cb_buffer_size': 485490688.0, 'romio_cb_read...         62
# 4  0.001249  {'cb_buffer_size': 413138944.0, 'romio_cb_read...         27
#
#    train_time  output
# 0    0.023241       0
# 1    0.024536       0
# 2    0.024737       0
# 3    0.024743       0
# 4    0.024921       0

# %%
import ast

# Convert from a string to a dictionary
ast.literal_eval(results.loc[0, 'params'])
best_bayes_params = ast.literal_eval(results.loc[0, 'params']).copy()
print(best_bayes_params)
log = open('best.txt','a')
print(results.loc[0,'output'])
print(results.loc[0,'output'],file=log)
log.close()
# Out:
# {'cb_buffer_size': 405798912.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 123.0, 'setstripe-size': 31916032.0}
# 0

# %%
bayes_params = pd.DataFrame(columns = list(ast.literal_eval(results.loc[0, 'params']).keys()),
                            index = list(range(len(results))))

# Add the results with each parameter a different column
for i, params in enumerate(results['params']):
    bayes_params.loc[i, :] = list(ast.literal_eval(params).values())
bayes_params['train_time'] = results['train_time']    
bayes_params['loss'] = results['loss']
bayes_params['iteration'] = results['iteration']
bayes_params['output']=results['output']

bayes_params.head()
# Out:
#   cb_buffer_size romio_cb_read romio_cb_write romio_ds_read romio_ds_write  \
# 0    4.05799e+08       disable        disable       disable        disable
# 1    3.12476e+08       disable        disable        enable         enable
# 2     3.0933e+08       disable        disable        enable         enable
# 3    4.85491e+08       disable         enable       disable        disable
# 4    4.13139e+08        enable        disable       disable        disable
#
#   setstripe-count setstripe-size  train_time      loss  iteration  output
# 0             123     3.1916e+07    0.023241  0.001170         57       0
# 1              68    3.00155e+07    0.024536  0.001078         88       0
# 2              22    2.62799e+07    0.024737  0.001154         89       0
# 3               5    1.61219e+07    0.024743  0.001325         62       0
# 4               9    2.92291e+07    0.024921  0.001249         27       0

# %%
#os.chdir('./plots')
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

# Density plots of the learning rate distributions 
sns.kdeplot(bayes_params['loss'], label = 'Loss Variation', linewidth = 2)
plt.legend()
plt.xlabel('Loss'); plt.ylabel('Density'); plt.title('Loss Distribution');
#plt.savefig(file_suffix+'_loss.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18


sns.kdeplot(bayes_params['cb_buffer_size'], label = 'bayes cb_buffer_size', linewidth = 2)
sns.kdeplot(cb_buffer_size_dist,color="red",linewidth=2, label = 'initial cb_buffer_size')

plt.legend()
plt.xlabel('cb_buffer_size'); plt.ylabel('Density'); plt.title('cb_buffer_size Distribution');
#plt.savefig(file_suffix+'_cb_buffer_size.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-size'], label = 'bayes setstripe-size', linewidth = 2)
sns.kdeplot(setstripe_size_dist,color="red",linewidth=2, label = 'initial setstripe-size')

plt.legend()
plt.xlabel('setstripe-size'); plt.ylabel('Density'); plt.title('setstripe-size Distribution');
#plt.savefig(file_suffix+'_setstripe-size.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-count'], label = 'bayes setstripe-count', linewidth = 2)
sns.kdeplot(setstripe_count_dist,color="red",linewidth=2, label = 'initial setstripe-count')

plt.legend()
plt.xlabel('setstripe-count'); plt.ylabel('Density'); plt.title('setstripe-count Distribution');
#plt.savefig(file_suffix+'_setstripe-count.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
from scipy.stats import itemfreq
plt.rcParams['font.size'] = 18
bayes_params['romio_ds_read'].value_counts().plot.bar()#plt.hist(romio_ds_read_dist,color="red",linewidth=2, label = 'initial romio_ds_read')

plt.legend()
plt.xlabel('romio_ds_read'); plt.ylabel('Count'); plt.title('romio_ds_read Distribution');
#plt.savefig(file_suffix+'_romio_ds_read.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

#plt.hist(bayes_params['romio_ds_write'], label = 'bayes romio_ds_write', linewidth = 2)
#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_ds_write')
bayes_params['romio_ds_write'].value_counts().plot.bar()
plt.legend()
plt.xlabel('romio_ds_write'); plt.ylabel('Count'); plt.title('romio_ds_write Distribution');
#plt.savefig(file_suffix+'_romio_ds_write.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_write'].value_counts().plot.bar()#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_cb_write')

plt.legend()
plt.xlabel('romio_cb_write'); plt.ylabel('Count'); plt.title('romio_cb_write Distribution');
#plt.savefig(file_suffix+'_romio_cb_write.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_read'].value_counts().plot.bar()#plt.hist(romio_cb_read_dist,color="red",linewidth=2, label = 'initial romio_cb_read')

plt.legend()
plt.xlabel('romio_cb_read'); plt.ylabel('Count'); plt.title('romio_cb_read Distribution');
#plt.savefig(file_suffix+'_romio_cb_read.png')

# %%
os.chdir('../')
