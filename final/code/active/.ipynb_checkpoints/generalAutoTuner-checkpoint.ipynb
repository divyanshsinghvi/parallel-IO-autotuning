# %%
# Data manipulation
import pandas as pd
import numpy as np
# Evaluation of the model
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 18
# %matplotlib inline
MAX_EVALS = 20
import csv
from hyperopt import STATUS_OK
from timeit import default_timer as timer
import json
import shlex
import subprocess
import logging
from pprint import pprint
import re
import os

# %%
file_suffix = "BT-IO-500-500-500-2" + str(MAX_EVALS)
def runthebenchmark(hyperparameters):
    os.chdir('/home/meghaagr/project/progress/active/../')
    storeinfile(hyperparameters)
    out=subprocess.Popen(["python3","bt_read_config_general.py","-n 2","-c500 500 500"], shell=False, stdout=subprocess.PIPE)
    logging.basicConfig(level=logging.DEBUG)
    output=out.stdout.read().decode('utf-8')
    print("output"+output)
    if len(output.split(" ")) > 5:
        values = output.split(" ")
        value = float(float(values[6])*1024)/float(values[5]) + float(float(values[3])*1024)/float(values[2])
        value = float(value)
        print(value)
        return float((value/100)),output
    return 0,0;

# %%
def storeinfile(hyperparameters):
    data={"mpi": {"romio_ds_read": "enable", "romio_ds_write": "disable"}, "lfs": {"setstripe": {"size": "16777216", "count": 4}}}
    data["lfs"]["setstripe"]["size"] = int(hyperparameters["setstripe-size"])
    data["lfs"]["setstripe"]["count"] = int(hyperparameters["setstripe-count"])

    data["mpi"]["romio_ds_read"] = hyperparameters["romio_ds_read"]
    data["mpi"]["romio_ds_write"] = hyperparameters["romio_ds_write"]
    data["mpi"]["romio_cb_read"] = hyperparameters["romio_cb_read"]
    data["mpi"]["romio_cb_write"] = hyperparameters["romio_cb_write"]
    data["mpi"]["cb_buffer_size"] = str(int(hyperparameters["cb_buffer_size"]))
    with open("confex.json","w") as fp:
        json.dump(data,fp)
    print(data)

# %%
def objective(hyperparameters):
    global ITERATION
    ITERATION += 1
    start = timer()
    result=0
    while(result == 0):
        print("rerun")
        result,output = runthebenchmark(hyperparameters)
        print(result)
    run_time = timer() - start
    print({'loss': result, 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK})
    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([float(result), hyperparameters, ITERATION, run_time, output])
    return {'loss': float(result), 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK}

# %%
from hyperopt import hp
from hyperopt.pyll.stochastic import sample

space = {
    'romio_ds_read' : hp.choice('romio_ds_read',['enable','disable']),
    'romio_ds_write' : hp.choice('romio_ds_write',['enable','disable']),
    'romio_cb_read' : hp.choice('romio_cb_read',['enable','disable']),
    'romio_cb_write' : hp.choice('romio_cb_write',['enable','disable']),
    'cb_buffer_size' : 1048576*hp.quniform('cb_buffer_size',1,512,1),
    'setstripe-size' : 65536*(hp.quniform('setstripe-size',0,512,1)),
    'setstripe-count' : hp.qloguniform('setstripe-count',0,5,1)
    
}

# %%
x = sample(space)
params = x
print(x)

cb_buffer_size_dist = []
for _ in range(1000):
    cb_buffer_size_dist.append(sample(space)['cb_buffer_size'])
    
setstripe_size_dist = []
for _ in range(1000):
    setstripe_size_dist.append(sample(space)['setstripe-size'])
    
setstripe_count_dist = []
for _ in range(1000):
    setstripe_count_dist.append(sample(space)['setstripe-count']) 
    
romio_ds_read_dist = []
for _ in range(20):
    romio_ds_read_dist.append(sample(space)['romio_ds_read'])
    
romio_ds_write_dist = []
for _ in range(20):
    romio_ds_write_dist.append(sample(space)['romio_ds_write'])
    
romio_cb_read_dist = []
for _ in range(20):
    romio_cb_read_dist.append(sample(space)['romio_cb_read']) 
    
romio_cb_write_dist = []
for _ in range(20):
    romio_cb_write_dist.append(sample(space)['romio_cb_write'])
# Out:
# {'cb_buffer_size': 441450496.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 10485760.0}

# %%
# File to save first results
print(os.getcwd())
out_file = '/home/meghaagr/project/progress/active/result/gbm_trials-'+file_suffix+'.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
writer.writerow(['loss', 'params', 'iteration', 'train_time', 'output'])
of_connection.close()
# Out:
# /home/meghaagr/project/progress/active

# %%
from hyperopt import tpe

# Create the algorithm
tpe_algorithm = tpe.suggest


from hyperopt import Trials

# Record results
bayes_trials = Trials()

from hyperopt import fmin


ITERATION = 20

best = fmin(fn = objective, space = space, algo = tpe.suggest, trials = bayes_trials, max_evals = MAX_EVALS)
# Out:
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '500170752'}, 'lfs': {'setstripe': {'size': 24969216, 'count': 15}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 813.05 14305.11 17.59 525.73 14305.11 27.21 24969216 15
#
# 45879.67786238511
# 96574191.2119854
# {'loss': 96574191.2119854, 'hyperparameters': {'cb_buffer_size': 500170752.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 15.0, 'setstripe-size': 24969216.0}, 'iteration': 21, 'iteration_time': 53.23111267015338, 'status': 'ok'}
#   5%|▌         | 1/20 [00:53<16:51, 53.26s/it, best loss: 96574191.2119854]
# INFO:hyperopt.tpe:tpe_transform took 0.006091 seconds
# INFO:hyperopt.tpe:TPE using 1/1 trials with best loss 96574191.211985
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '26214400'}, 'lfs': {'setstripe': {'size': 4718592, 'count': 29}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 115.62 14305.11 123.73 426.11 14305.11 33.57 4718592 29
#
# 161071.74123601866
# 4178862300.012545
# {'loss': 4178862300.012545, 'hyperparameters': {'cb_buffer_size': 26214400.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 29.0, 'setstripe-size': 4718592.0}, 'iteration': 22, 'iteration_time': 165.59800191689283, 'status': 'ok'}
#  10%|█         | 2/20 [03:38<26:05, 86.97s/it, best loss: 96574191.2119854]
# INFO:hyperopt.tpe:tpe_transform took 0.009509 seconds
# INFO:hyperopt.tpe:TPE using 2/2 trials with best loss 96574191.211985
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '182452224'}, 'lfs': {'setstripe': {'size': 11993088, 'count': 10}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 775.34 14305.11 18.45 430.12 14305.11 33.26 11993088 10
#
# 52949.533147920374
# 148452120.66659307
# {'loss': 148452120.66659307, 'hyperparameters': {'cb_buffer_size': 182452224.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 10.0, 'setstripe-size': 11993088.0}, 'iteration': 23, 'iteration_time': 59.880827573128045, 'status': 'ok'}
#  15%|█▌        | 3/20 [04:38<22:20, 78.85s/it, best loss: 96574191.2119854]
# INFO:hyperopt.tpe:tpe_transform took 0.009573 seconds
# INFO:hyperopt.tpe:TPE using 3/3 trials with best loss 96574191.211985
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '470810624'}, 'lfs': {'setstripe': {'size': 6553600, 'count': 3}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 604.73 14305.11 23.66 520.87 14305.11 27.46 6553600 3
#
# 52346.10647136613
# 143434344.34727418
# {'loss': 143434344.34727418, 'hyperparameters': {'cb_buffer_size': 470810624.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 3.0, 'setstripe-size': 6553600.0}, 'iteration': 24, 'iteration_time': 59.35327983554453, 'status': 'ok'}
#  20%|██        | 4/20 [05:38<19:28, 73.01s/it, best loss: 96574191.2119854]
# INFO:hyperopt.tpe:tpe_transform took 0.009567 seconds
# INFO:hyperopt.tpe:TPE using 4/4 trials with best loss 96574191.211985
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '362807296'}, 'lfs': {'setstripe': {'size': 6356992, 'count': 7}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 708.26 14305.11 20.20 577.80 14305.11 24.76 6356992 7
#
# 46034.36283433002
# 97554298.26390764
# {'loss': 97554298.26390764, 'hyperparameters': {'cb_buffer_size': 362807296.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 7.0, 'setstripe-size': 6356992.0}, 'iteration': 25, 'iteration_time': 53.26934229955077, 'status': 'ok'}
#  25%|██▌       | 5/20 [06:31<16:46, 67.10s/it, best loss: 96574191.2119854]
# INFO:hyperopt.tpe:tpe_transform took 0.011133 seconds
# INFO:hyperopt.tpe:TPE using 5/5 trials with best loss 96574191.211985
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '29360128'}, 'lfs': {'setstripe': {'size': 28704768, 'count': 60}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 823.42 14305.11 17.37 534.88 14305.11 26.74 28704768 60
#
# 45176.13665331797
# 92199223.88967812
# {'loss': 92199223.88967812, 'hyperparameters': {'cb_buffer_size': 29360128.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 60.0, 'setstripe-size': 28704768.0}, 'iteration': 26, 'iteration_time': 52.32271836139262, 'status': 'ok'}
#  30%|███       | 6/20 [07:23<14:37, 62.67s/it, best loss: 92199223.88967812]
# INFO:hyperopt.tpe:tpe_transform took 0.010057 seconds
# INFO:hyperopt.tpe:TPE using 6/6 trials with best loss 92199223.889678
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '527433728'}, 'lfs': {'setstripe': {'size': 12189696, 'count': 1}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 113.81 14305.11 125.69 447.64 14305.11 31.96 12189696 1
#
# 161433.22916444455
# 4207060933.893216
# {'loss': 4207060933.893216, 'hyperparameters': {'cb_buffer_size': 527433728.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 1.0, 'setstripe-size': 12189696.0}, 'iteration': 27, 'iteration_time': 166.12605813052505, 'status': 'ok'}
#  35%|███▌      | 7/20 [10:09<20:18, 93.72s/it, best loss: 92199223.88967812]
# INFO:hyperopt.tpe:tpe_transform took 0.009852 seconds
# INFO:hyperopt.tpe:TPE using 7/7 trials with best loss 92199223.889678
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '338690048'}, 'lfs': {'setstripe': {'size': 9568256, 'count': 2}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 598.35 14305.11 23.91 530.24 14305.11 26.98 9568256 2
#
# 52107.420435043685
# 141481195.9159938
# {'loss': 141481195.9159938, 'hyperparameters': {'cb_buffer_size': 338690048.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 9568256.0}, 'iteration': 28, 'iteration_time': 59.54633960593492, 'status': 'ok'}
#  40%|████      | 8/20 [11:09<16:41, 83.48s/it, best loss: 92199223.88967812]
# INFO:hyperopt.tpe:tpe_transform took 0.009753 seconds
# INFO:hyperopt.tpe:TPE using 8/8 trials with best loss 92199223.889678
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '283115520'}, 'lfs': {'setstripe': {'size': 12320768, 'count': 3}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 752.33 14305.11 19.01 610.98 14305.11 23.41 12320768 3
#
# 43446.06067120904
# 82007054.44173242
# {'loss': 82007054.44173242, 'hyperparameters': {'cb_buffer_size': 283115520.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 3.0, 'setstripe-size': 12320768.0}, 'iteration': 29, 'iteration_time': 50.85869864560664, 'status': 'ok'}
#  45%|████▌     | 9/20 [12:00<13:30, 73.70s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009592 seconds
# INFO:hyperopt.tpe:TPE using 9/9 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '55574528'}, 'lfs': {'setstripe': {'size': 26083328, 'count': 76}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 264.56 14305.11 54.07 233.64 14305.11 61.23 26083328 76
#
# 118065.63358700142
# 1645775171.428738
# {'loss': 1645775171.428738, 'hyperparameters': {'cb_buffer_size': 55574528.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 76.0, 'setstripe-size': 26083328.0}, 'iteration': 30, 'iteration_time': 123.84690267313272, 'status': 'ok'}
#  50%|█████     | 10/20 [14:04<14:47, 88.75s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.008230 seconds
# INFO:hyperopt.tpe:TPE using 10/10 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '412090368'}, 'lfs': {'setstripe': {'size': 11468800, 'count': 52}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 568.86 14305.11 25.15 347.11 14305.11 41.21 11468800 52
#
# 67951.6310497962
# 313761503.0789012
# {'loss': 313761503.0789012, 'hyperparameters': {'cb_buffer_size': 412090368.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 52.0, 'setstripe-size': 11468800.0}, 'iteration': 31, 'iteration_time': 74.90981377474964, 'status': 'ok'}
#  55%|█████▌    | 11/20 [15:19<12:41, 84.61s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.010836 seconds
# INFO:hyperopt.tpe:TPE using 11/11 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '435159040'}, 'lfs': {'setstripe': {'size': 25559040, 'count': 10}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 575.44 14305.11 24.86 392.90 14305.11 36.41 25559040 10
#
# 62738.90783665025
# 246951041.7758293
# {'loss': 246951041.7758293, 'hyperparameters': {'cb_buffer_size': 435159040.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 10.0, 'setstripe-size': 25559040.0}, 'iteration': 32, 'iteration_time': 69.88644258864224, 'status': 'ok'}
#  60%|██████    | 12/20 [16:29<10:41, 80.20s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009480 seconds
# INFO:hyperopt.tpe:TPE using 12/12 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '8388608'}, 'lfs': {'setstripe': {'size': 12124160, 'count': 8}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 59.46 14305.11 240.60 422.99 14305.11 33.82 12124160 8
#
# 280988.4469643086
# 22185304394.762203
# {'loss': 22185304394.762203, 'hyperparameters': {'cb_buffer_size': 8388608.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 8.0, 'setstripe-size': 12124160.0}, 'iteration': 33, 'iteration_time': 282.5505438828841, 'status': 'ok'}
#  65%|██████▌   | 13/20 [21:11<16:26, 140.91s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009925 seconds
# INFO:hyperopt.tpe:TPE using 13/13 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '123731968'}, 'lfs': {'setstripe': {'size': 22609920, 'count': 17}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 777.20 14305.11 18.41 465.76 14305.11 30.71 22609920 17
#
# 50298.302799415775
# 127250645.22398259
# {'loss': 127250645.22398259, 'hyperparameters': {'cb_buffer_size': 123731968.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 17.0, 'setstripe-size': 22609920.0}, 'iteration': 34, 'iteration_time': 57.225087312050164, 'status': 'ok'}
#  70%|███████   | 14/20 [22:09<11:34, 115.82s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.011770 seconds
# INFO:hyperopt.tpe:TPE using 14/14 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '499122176'}, 'lfs': {'setstripe': {'size': 6881280, 'count': 33}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 856.86 14305.11 16.69 402.89 14305.11 35.51 6881280 33
#
# 53453.87180450181
# 152734625.13272622
# {'loss': 152734625.13272622, 'hyperparameters': {'cb_buffer_size': 499122176.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 33.0, 'setstripe-size': 6881280.0}, 'iteration': 35, 'iteration_time': 60.31086534727365, 'status': 'ok'}
#  75%|███████▌  | 15/20 [23:09<08:15, 99.18s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009657 seconds
# INFO:hyperopt.tpe:TPE using 15/15 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '156237824'}, 'lfs': {'setstripe': {'size': 8257536, 'count': 88}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 59.34 14305.11 241.07 416.53 14305.11 34.34 8257536 88
#
# 282023.73292077007
# 22431430486.89812
# {'loss': 22431430486.89812, 'hyperparameters': {'cb_buffer_size': 156237824.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 88.0, 'setstripe-size': 8257536.0}, 'iteration': 36, 'iteration_time': 283.6745982943103, 'status': 'ok'}
#  80%|████████  | 16/20 [27:53<10:18, 154.53s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009611 seconds
# INFO:hyperopt.tpe:TPE using 16/16 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '243269632'}, 'lfs': {'setstripe': {'size': 32964608, 'count': 4}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 694.15 14305.11 20.61 569.88 14305.11 25.10 32964608 4
#
# 46807.106629987364
# 102549934.76693772
# {'loss': 102549934.76693772, 'hyperparameters': {'cb_buffer_size': 243269632.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 4.0, 'setstripe-size': 32964608.0}, 'iteration': 37, 'iteration_time': 53.99858952779323, 'status': 'ok'}
#  85%|████████▌ | 17/20 [28:47<06:13, 124.38s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009605 seconds
# INFO:hyperopt.tpe:TPE using 17/17 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '76546048'}, 'lfs': {'setstripe': {'size': 12124160, 'count': 68}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 803.63 14305.11 17.80 458.12 14305.11 31.23 12124160 68
#
# 50202.93163679696
# 126528172.82033749
# {'loss': 126528172.82033749, 'hyperparameters': {'cb_buffer_size': 76546048.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 68.0, 'setstripe-size': 12124160.0}, 'iteration': 38, 'iteration_time': 57.16716137249023, 'status': 'ok'}
#  90%|█████████ | 18/20 [29:44<03:28, 104.23s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.009656 seconds
# INFO:hyperopt.tpe:TPE using 18/18 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '524288000'}, 'lfs': {'setstripe': {'size': 29425664, 'count': 126}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 116.22 14305.11 123.09 536.70 14305.11 26.65 29425664 126
#
# 153334.0701526826
# 3605089007.6115413
# {'loss': 3605089007.6115413, 'hyperparameters': {'cb_buffer_size': 524288000.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 126.0, 'setstripe-size': 29425664.0}, 'iteration': 39, 'iteration_time': 158.04385512694716, 'status': 'ok'}
#  95%|█████████▌| 19/20 [32:22<02:00, 120.38s/it, best loss: 82007054.44173242]
# INFO:hyperopt.tpe:tpe_transform took 0.010124 seconds
# INFO:hyperopt.tpe:TPE using 19/19 trials with best loss 82007054.441732
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '509607936'}, 'lfs': {'setstripe': {'size': 30998528, 'count': 10}}}
# outputbtio-pnetcdf-1.1.1 500-500-500 797.63 14305.11 17.93 369.33 14305.11 38.73 30998528 10
#
# 58027.12614469811
# 195385885.1062778
# {'loss': 195385885.1062778, 'hyperparameters': {'cb_buffer_size': 509607936.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 10.0, 'setstripe-size': 30998528.0}, 'iteration': 40, 'iteration_time': 67.00779452547431, 'status': 'ok'}
# 100%|██████████| 20/20 [33:29<00:00, 104.38s/it, best loss: 82007054.44173242]

# %%
print(best)
d=  best
#print(bayes_trials.results)
bayes_trials_results = sorted(bayes_trials.results, key = lambda x: x['loss'])
#bayes_trials_results[:1]
# Out:
# {'cb_buffer_size': 270.0, 'romio_cb_read': 1, 'romio_cb_write': 0, 'romio_ds_read': 0, 'romio_ds_write': 1, 'setstripe-count': 3.0, 'setstripe-size': 188.0}

# %%
results = pd.read_csv(out_file)

# Sort with best scores on top and reset index for slicing
results.sort_values('train_time', ascending = True, inplace = True)
results.reset_index(inplace = True, drop = True)
results.head()
# Out:
#            loss                                             params  iteration  \
# 0  8.200705e+07  {'cb_buffer_size': 283115520.0, 'romio_cb_read...         29
# 1  9.219922e+07  {'cb_buffer_size': 29360128.0, 'romio_cb_read'...         26
# 2  9.657419e+07  {'cb_buffer_size': 500170752.0, 'romio_cb_read...         21
# 3  9.755430e+07  {'cb_buffer_size': 362807296.0, 'romio_cb_read...         25
# 4  1.025499e+08  {'cb_buffer_size': 243269632.0, 'romio_cb_read...         37
#
#    train_time                                             output
# 0   50.858699  btio-pnetcdf-1.1.1 500-500-500 752.33 14305.11...
# 1   52.322718  btio-pnetcdf-1.1.1 500-500-500 823.42 14305.11...
# 2   53.231113  btio-pnetcdf-1.1.1 500-500-500 813.05 14305.11...
# 3   53.269342  btio-pnetcdf-1.1.1 500-500-500 708.26 14305.11...
# 4   53.998590  btio-pnetcdf-1.1.1 500-500-500 694.15 14305.11...

# %%
import ast

# Convert from a string to a dictionary
ast.literal_eval(results.loc[0, 'params'])
best_bayes_params = ast.literal_eval(results.loc[0, 'params']).copy()
print(best_bayes_params)
log = open('bt_best.txt','a')
print(results.loc[0,'output'])
print(results.loc[0,'output'],file=log)
log.close()
# Out:
# {'cb_buffer_size': 283115520.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 3.0, 'setstripe-size': 12320768.0}
# btio-pnetcdf-1.1.1 500-500-500 752.33 14305.11 19.01 610.98 14305.11 23.41 12320768 3

# %%
bayes_params = pd.DataFrame(columns = list(ast.literal_eval(results.loc[0, 'params']).keys()),
                            index = list(range(len(results))))

# Add the results with each parameter a different column
for i, params in enumerate(results['params']):
    bayes_params.loc[i, :] = list(ast.literal_eval(params).values())
bayes_params['train_time'] = results['train_time']    
bayes_params['loss'] = results['loss']
bayes_params['iteration'] = results['iteration']
bayes_params['output']=results['output']

bayes_params.head()
# Out:
#   cb_buffer_size romio_cb_read romio_cb_write romio_ds_read romio_ds_write  \
# 0    2.83116e+08       disable         enable        enable        disable
# 1    2.93601e+07        enable         enable        enable        disable
# 2    5.00171e+08        enable         enable       disable        disable
# 3    3.62807e+08        enable        disable       disable        disable
# 4     2.4327e+08       disable        disable        enable         enable
#
#   setstripe-count setstripe-size  train_time          loss  iteration  \
# 0               3    1.23208e+07   50.858699  8.200705e+07         29
# 1              60    2.87048e+07   52.322718  9.219922e+07         26
# 2              15    2.49692e+07   53.231113  9.657419e+07         21
# 3               7    6.35699e+06   53.269342  9.755430e+07         25
# 4               4    3.29646e+07   53.998590  1.025499e+08         37
#
#                                               output
# 0  btio-pnetcdf-1.1.1 500-500-500 752.33 14305.11...
# 1  btio-pnetcdf-1.1.1 500-500-500 823.42 14305.11...
# 2  btio-pnetcdf-1.1.1 500-500-500 813.05 14305.11...
# 3  btio-pnetcdf-1.1.1 500-500-500 708.26 14305.11...
# 4  btio-pnetcdf-1.1.1 500-500-500 694.15 14305.11...

# %%
os.chdir('./bt_plots')
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

# Density plots of the learning rate distributions 
sns.kdeplot(bayes_params['loss'], label = 'Loss Variation', linewidth = 2)
plt.legend()
plt.xlabel('Loss'); plt.ylabel('Density'); plt.title('Loss Distribution');
plt.savefig(file_suffix+'_loss.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=18.0 to DejaVu Sans ('/home/meghaagr/env/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=21.599999999999998 to DejaVu Sans ('/home/meghaagr/env/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18


sns.kdeplot(bayes_params['cb_buffer_size'], label = 'bayes cb_buffer_size', linewidth = 2)
sns.kdeplot(cb_buffer_size_dist,color="red",linewidth=2, label = 'initial cb_buffer_size')

plt.legend()
plt.xlabel('cb_buffer_size'); plt.ylabel('Density'); plt.title('cb_buffer_size Distribution');
plt.savefig(file_suffix+'_cb_buffer_size.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-size'], label = 'bayes setstripe-size', linewidth = 2)
sns.kdeplot(setstripe_size_dist,color="red",linewidth=2, label = 'initial setstripe-size')

plt.legend()
plt.xlabel('setstripe-size'); plt.ylabel('Density'); plt.title('setstripe-size Distribution');
plt.savefig(file_suffix+'_setstripe-size.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-count'], label = 'bayes setstripe-count', linewidth = 2)
sns.kdeplot(setstripe_count_dist,color="red",linewidth=2, label = 'initial setstripe-count')

plt.legend()
plt.xlabel('setstripe-count'); plt.ylabel('Density'); plt.title('setstripe-count Distribution');
plt.savefig(file_suffix+'_setstripe-count.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
from scipy.stats import itemfreq
plt.rcParams['font.size'] = 18
bayes_params['romio_ds_read'].value_counts().plot.bar()#plt.hist(romio_ds_read_dist,color="red",linewidth=2, label = 'initial romio_ds_read')

plt.legend()
plt.xlabel('romio_ds_read'); plt.ylabel('Count'); plt.title('romio_ds_read Distribution');
plt.savefig(file_suffix+'_romio_ds_read.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

#plt.hist(bayes_params['romio_ds_write'], label = 'bayes romio_ds_write', linewidth = 2)
#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_ds_write')
bayes_params['romio_ds_write'].value_counts().plot.bar()
plt.legend()
plt.xlabel('romio_ds_write'); plt.ylabel('Count'); plt.title('romio_ds_write Distribution');
plt.savefig(file_suffix+'_romio_ds_write.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_write'].value_counts().plot.bar()#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_cb_write')

plt.legend()
plt.xlabel('romio_cb_write'); plt.ylabel('Count'); plt.title('romio_cb_write Distribution');
plt.savefig(file_suffix+'_romio_cb_write.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_read'].value_counts().plot.bar()#plt.hist(romio_cb_read_dist,color="red",linewidth=2, label = 'initial romio_cb_read')

plt.legend()
plt.xlabel('romio_cb_read'); plt.ylabel('Count'); plt.title('romio_cb_read Distribution');
plt.savefig(file_suffix+'_romio_cb_read.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
os.chdir('../')
