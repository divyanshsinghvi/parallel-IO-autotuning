# %%
# Data manipulation
import pandas as pd
import numpy as np
# Evaluation of the model
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 18
# %matplotlib inline
MAX_EVALS = 1000
import csv
from hyperopt import STATUS_OK
from timeit import default_timer as timer
import json
import shlex
import subprocess
import logging
from pprint import pprint
import re
import os

# %%
file_suffix = "temp" + str(MAX_EVALS)
def runthebenchmark(hyperparameters):
    os.chdir('/home/meghaagr/project/progress/active/../')
    storeinfile(hyperparameters)
    out=subprocess.Popen(["python3","read_config_general.py","-n 8","-c200 200 400 4 4 4 1"], shell=False, stdout=subprocess.PIPE)
    logging.basicConfig(level=logging.DEBUG)
    output=out.stdout.read().decode('utf-8')
    print("output"+output)
    if len(output.split(" ")) > 5:
        values = output.split(" ")
        value = float(float(values[6])*1024)/float(values[5]) + float(float(values[3])*1024)/float(values[2])
        value = float(value)
        print(value)
        return float((value/100)**3),output
    return 0,0

# %%
import json
from sklearn.externals import joblib
import os
os.chdir('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active')


# Loading the model and scaler
filename="finalxgb.sav"
loaded_model = joblib.load(open(filename, 'rb'))
scaler_filename = "scalerxgb.save"
scaler = joblib.load(scaler_filename)

# %%
def runfromsavedmodel(hyperparameters):
### INITIALIZE THIS MANUALLY ####
    nx_g = 400
    ny_g = 400
    nz_g = 800
    npx  = 4
    npy  = 4 
    npz  = 8
   # Active learning model choosees and saves the values of parameters
    storeinfile(hyperparameters)
    with open('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json') as f:
        data = json.load(f)

    romio_ds_read = data["mpi"]["romio_ds_read"] == "enable"
    romio_ds_write = data["mpi"]["romio_ds_write"] == "enable"
    cb_buffer_size = data["mpi"]["cb_buffer_size"]
    stripe_size = data["lfs"]["setstripe"]["size"]
    stripe_count = data["lfs"]["setstripe"]["count"]
    col_names =  ['cb5','cb6','cb7','cb8','cb8','cb10','cb11','cb12']
    cb_df  = pd.DataFrame(columns = col_names)
    cb_df.loc[len(cb_df)] = [romio_ds_read, romio_ds_write, stripe_size, stripe_count, cb_buffer_size,str(nx_g/npx),str(ny_g/npy),str(nz_g/npz)]


    col_names =  ['0','1', '2','3','4','5']
    my_df = pd.DataFrame(columns=col_names)
    

    my_df.loc[len(my_df)] = [nx_g,ny_g,nz_g,npx,npy,npz]
    x = pd.concat([my_df,cb_df], axis=1)
    #normalize the test data
    norm_df = pd.DataFrame(scaler.transform(x))
    out = loaded_model.predict(norm_df)
    return float(1/float(out[0])),0

# %%
# # Import section
# import pickle
# import json
# from sklearn.externals import joblib
# import os
# os.chdir('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active')


# # Loading the model and scaler
# filename="final.sav"
# loaded_model = pickle.load(open(filename, 'rb'))
# scaler_filename = "scaler.save"
# scaler = joblib.load(scaler_filename)

# %%
# def runfromsavedmodel(hyperparameters):
#    # Active learning model choosees and saves the values of parameters
#     storeinfile(hyperparameters)
#     with open('/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json') as f:
#         data = json.load(f)

#     cb_buffer_size = data["mpi"]["cb_buffer_size"]
#     stripe_size = data["lfs"]["setstripe"]["size"]
#     stripe_count = data["lfs"]["setstripe"]["count"]
#     col_names =  ['cb1', 'cb2', 'cb3']
#     cb_df  = pd.DataFrame(columns = col_names)
#     cb_df.loc[len(cb_df)] = [stripe_size, stripe_count, cb_buffer_size]

#     #normalize the test data
#     norm_df = scaler.transform( cb_df )
#     temp = pd.DataFrame(norm_df)

#     col_names =  ['0','1', '2','3','4','5']
#     my_df = pd.DataFrame(columns=col_names)
    
#     ### INITIALIZE THIS MANUALLY ####
#     my_df.loc[len(my_df)] = [300,300,300,2,2,4]
#     x = pd.concat([my_df,temp], axis=1)
#     out = loaded_model.predict(x)
#     return float(1/float(out[0])),0

# %%
def storeinfile(hyperparameters):
    data={"mpi": {"romio_ds_read": "enable", "romio_ds_write": "disable"}, "lfs": {"setstripe": {"size": "16777216", "count": 4}}}
    data["lfs"]["setstripe"]["size"] = int(hyperparameters["setstripe-size"])
    data["lfs"]["setstripe"]["count"] = int(hyperparameters["setstripe-count"])

    data["mpi"]["romio_ds_read"] = hyperparameters["romio_ds_read"]
    data["mpi"]["romio_ds_write"] = hyperparameters["romio_ds_write"]
    data["mpi"]["romio_cb_read"] = hyperparameters["romio_cb_read"]
    data["mpi"]["romio_cb_write"] = hyperparameters["romio_cb_write"]
    data["mpi"]["cb_buffer_size"] = str(int(hyperparameters["cb_buffer_size"]))
    with open("/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/confex.json","w") as fp:
        json.dump(data,fp)
    print(data)

# %%
def objective(hyperparameters):
    global ITERATION
    ITERATION += 1
    start = timer()
    result=0
    while(result == 0):
        print("rerun")
        result,output = runfromsavedmodel(hyperparameters)
        print(result)
    run_time = timer() - start
    print({'loss': result, 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK})
    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([float(result), hyperparameters, ITERATION, run_time, output])
    return {'loss': float(result), 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK}

# %%
from hyperopt import hp
from hyperopt.pyll.stochastic import sample

space = {
    'romio_ds_read' : hp.choice('romio_ds_read',['enable','disable']),
    'romio_ds_write' : hp.choice('romio_ds_write',['enable','disable']),
    'romio_cb_read' : hp.choice('romio_cb_read',['enable','disable']),
    'romio_cb_write' : hp.choice('romio_cb_write',['enable','disable']),
    'cb_buffer_size' : 1048576*hp.quniform('cb_buffer_size',1,512,1),
    'setstripe-size' : 65536*(hp.quniform('setstripe-size',0,512,1)),
    'setstripe-count' : hp.qloguniform('setstripe-count',0,5,1)
    
}

# %%
x = sample(space)
params = x
print(x)

cb_buffer_size_dist = []
for _ in range(1000):
    cb_buffer_size_dist.append(sample(space)['cb_buffer_size'])
    
setstripe_size_dist = []
for _ in range(1000):
    setstripe_size_dist.append(sample(space)['setstripe-size'])
    
setstripe_count_dist = []
for _ in range(1000):
    setstripe_count_dist.append(sample(space)['setstripe-count']) 
    
romio_ds_read_dist = []
for _ in range(20):
    romio_ds_read_dist.append(sample(space)['romio_ds_read'])
    
romio_ds_write_dist = []
for _ in range(20):
    romio_ds_write_dist.append(sample(space)['romio_ds_write'])
    
romio_cb_read_dist = []
for _ in range(20):
    romio_cb_read_dist.append(sample(space)['romio_cb_read']) 
    
romio_cb_write_dist = []
for _ in range(20):
    romio_cb_write_dist.append(sample(space)['romio_cb_write'])
# Out:
# {'cb_buffer_size': 490733568.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 122.0, 'setstripe-size': 31457280.0}

# %%
# File to save first results
print(os.getcwd())
out_file = '/home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active/result/gbm_trials-'+file_suffix+'.csv'

of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
writer.writerow(['loss', 'params', 'iteration', 'train_time', 'output'])
of_connection.close()
# Out:
# /home/dsinghvi/sem8/parallel/project/CS633-2018-19-2-project/progress/active

# %%
from hyperopt import tpe

# Create the algorithm
tpe_algorithm = tpe.suggest


from hyperopt import Trials

# Record results
bayes_trials = Trials()

from hyperopt import fmin


ITERATION = 1

best = fmin(fn = objective, space = space, algo = tpe.suggest, trials = bayes_trials, max_evals = MAX_EVALS)
# Out:
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '242221056'}, 'lfs': {'setstripe': {'size': 458752, 'count': 38}}}
# 0.0010076671637964081
# {'loss': 0.0010076671637964081, 'hyperparameters': {'cb_buffer_size': 242221056.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 38.0, 'setstripe-size': 458752.0}, 'iteration': 2, 'iteration_time': 0.058595664999302244, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '178257920'}, 'lfs': {'setstripe': {'size': 9961472, 'count': 3}}}
# 0.0012423398269550436
# {'loss': 0.0012423398269550436, 'hyperparameters': {'cb_buffer_size': 178257920.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 3.0, 'setstripe-size': 9961472.0}, 'iteration': 3, 'iteration_time': 0.039886872000352014, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '379584512'}, 'lfs': {'setstripe': {'size': 22020096, 'count': 25}}}
# 0.0011354878772253732
# {'loss': 0.0011354878772253732, 'hyperparameters': {'cb_buffer_size': 379584512.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 25.0, 'setstripe-size': 22020096.0}, 'iteration': 4, 'iteration_time': 0.041126702999463305, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '529530880'}, 'lfs': {'setstripe': {'size': 14286848, 'count': 3}}}
# 0.0011368611045635356
# {'loss': 0.0011368611045635356, 'hyperparameters': {'cb_buffer_size': 529530880.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 3.0, 'setstripe-size': 14286848.0}, 'iteration': 5, 'iteration_time': 0.06095818899848382, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '386924544'}, 'lfs': {'setstripe': {'size': 22609920, 'count': 7}}}
# 0.001109333391111114
# {'loss': 0.001109333391111114, 'hyperparameters': {'cb_buffer_size': 386924544.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 22609920.0}, 'iteration': 6, 'iteration_time': 0.0784421639982611, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '493879296'}, 'lfs': {'setstripe': {'size': 6160384, 'count': 75}}}
# 0.0011770265453107088
# {'loss': 0.0011770265453107088, 'hyperparameters': {'cb_buffer_size': 493879296.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 75.0, 'setstripe-size': 6160384.0}, 'iteration': 7, 'iteration_time': 0.05029861000002711, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '214958080'}, 'lfs': {'setstripe': {'size': 3932160, 'count': 1}}}
# 0.0017519273446303277
# {'loss': 0.0017519273446303277, 'hyperparameters': {'cb_buffer_size': 214958080.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 1.0, 'setstripe-size': 3932160.0}, 'iteration': 8, 'iteration_time': 0.03941324700281257, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '158334976'}, 'lfs': {'setstripe': {'size': 31391744, 'count': 7}}}
# 0.0011690292583392693
# {'loss': 0.0011690292583392693, 'hyperparameters': {'cb_buffer_size': 158334976.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 31391744.0}, 'iteration': 9, 'iteration_time': 0.0723231490010221, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '517996544'}, 'lfs': {'setstripe': {'size': 22020096, 'count': 62}}}
# 0.0011282173112909528
# {'loss': 0.0011282173112909528, 'hyperparameters': {'cb_buffer_size': 517996544.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 62.0, 'setstripe-size': 22020096.0}, 'iteration': 10, 'iteration_time': 0.05435600900091231, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '509607936'}, 'lfs': {'setstripe': {'size': 26738688, 'count': 6}}}
# 0.001109333391111114
# {'loss': 0.001109333391111114, 'hyperparameters': {'cb_buffer_size': 509607936.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 6.0, 'setstripe-size': 26738688.0}, 'iteration': 11, 'iteration_time': 0.06052101900058915, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '416284672'}, 'lfs': {'setstripe': {'size': 15204352, 'count': 9}}}
# 0.0011201717122594466
# {'loss': 0.0011201717122594466, 'hyperparameters': {'cb_buffer_size': 416284672.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 9.0, 'setstripe-size': 15204352.0}, 'iteration': 12, 'iteration_time': 0.07342709999647923, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '522190848'}, 'lfs': {'setstripe': {'size': 28442624, 'count': 75}}}
# 0.0011311911814589038
# {'loss': 0.0011311911814589038, 'hyperparameters': {'cb_buffer_size': 522190848.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 75.0, 'setstripe-size': 28442624.0}, 'iteration': 13, 'iteration_time': 0.06614513300155522, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '204472320'}, 'lfs': {'setstripe': {'size': 4849664, 'count': 111}}}
# 0.0012407824532883348
# {'loss': 0.0012407824532883348, 'hyperparameters': {'cb_buffer_size': 204472320.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 111.0, 'setstripe-size': 4849664.0}, 'iteration': 14, 'iteration_time': 0.03731884299850208, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '31457280'}, 'lfs': {'setstripe': {'size': 3735552, 'count': 108}}}
# 0.0018639977883229367
# {'loss': 0.0018639977883229367, 'hyperparameters': {'cb_buffer_size': 31457280.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 108.0, 'setstripe-size': 3735552.0}, 'iteration': 15, 'iteration_time': 0.039941151000675745, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '390070272'}, 'lfs': {'setstripe': {'size': 9043968, 'count': 2}}}
# 0.0013999757328425216
# {'loss': 0.0013999757328425216, 'hyperparameters': {'cb_buffer_size': 390070272.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 9043968.0}, 'iteration': 16, 'iteration_time': 0.05093703199963784, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '41943040'}, 'lfs': {'setstripe': {'size': 23855104, 'count': 3}}}
# 0.001832613199714236
# {'loss': 0.001832613199714236, 'hyperparameters': {'cb_buffer_size': 41943040.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 3.0, 'setstripe-size': 23855104.0}, 'iteration': 17, 'iteration_time': 0.04365508100090665, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '423624704'}, 'lfs': {'setstripe': {'size': 22872064, 'count': 58}}}
# 0.0011394296342391928
# {'loss': 0.0011394296342391928, 'hyperparameters': {'cb_buffer_size': 423624704.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 58.0, 'setstripe-size': 22872064.0}, 'iteration': 18, 'iteration_time': 0.058038701001351, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '411041792'}, 'lfs': {'setstripe': {'size': 25952256, 'count': 126}}}
# 0.0013117511413371823
# {'loss': 0.0013117511413371823, 'hyperparameters': {'cb_buffer_size': 411041792.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 126.0, 'setstripe-size': 25952256.0}, 'iteration': 19, 'iteration_time': 0.05674442400049884, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '24117248'}, 'lfs': {'setstripe': {'size': 4063232, 'count': 11}}}
# 0.001867802365898197
# {'loss': 0.001867802365898197, 'hyperparameters': {'cb_buffer_size': 24117248.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 11.0, 'setstripe-size': 4063232.0}, 'iteration': 20, 'iteration_time': 0.04608895300043514, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '223346688'}, 'lfs': {'setstripe': {'size': 13434880, 'count': 18}}}
# 0.0011778922056089065
# {'loss': 0.0011778922056089065, 'hyperparameters': {'cb_buffer_size': 223346688.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 18.0, 'setstripe-size': 13434880.0}, 'iteration': 21, 'iteration_time': 0.03583838299891795, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '306184192'}, 'lfs': {'setstripe': {'size': 17432576, 'count': 28}}}
# 0.0011243526171290427
# {'loss': 0.0011243526171290427, 'hyperparameters': {'cb_buffer_size': 306184192.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 28.0, 'setstripe-size': 17432576.0}, 'iteration': 22, 'iteration_time': 0.05838796100215404, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '103809024'}, 'lfs': {'setstripe': {'size': 33226752, 'count': 39}}}
# 0.0012078487759178073
# {'loss': 0.0012078487759178073, 'hyperparameters': {'cb_buffer_size': 103809024.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 39.0, 'setstripe-size': 33226752.0}, 'iteration': 23, 'iteration_time': 0.05201321800268488, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '297795584'}, 'lfs': {'setstripe': {'size': 18874368, 'count': 17}}}
# 0.0011068992100844572
# {'loss': 0.0011068992100844572, 'hyperparameters': {'cb_buffer_size': 297795584.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 17.0, 'setstripe-size': 18874368.0}, 'iteration': 24, 'iteration_time': 0.07606612800009316, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '313524224'}, 'lfs': {'setstripe': {'size': 18546688, 'count': 17}}}
# 0.0011068992100844572
# {'loss': 0.0011068992100844572, 'hyperparameters': {'cb_buffer_size': 313524224.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 17.0, 'setstripe-size': 18546688.0}, 'iteration': 25, 'iteration_time': 0.056356425000558374, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '269484032'}, 'lfs': {'setstripe': {'size': 196608, 'count': 40}}}
# 0.0010076671637964081
# {'loss': 0.0010076671637964081, 'hyperparameters': {'cb_buffer_size': 269484032.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 40.0, 'setstripe-size': 196608.0}, 'iteration': 26, 'iteration_time': 0.04926009999689995, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '131072000'}, 'lfs': {'setstripe': {'size': 7667712, 'count': 40}}}
# 0.0012119713834500957
# {'loss': 0.0012119713834500957, 'hyperparameters': {'cb_buffer_size': 131072000.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 40.0, 'setstripe-size': 7667712.0}, 'iteration': 27, 'iteration_time': 0.04048341999805416, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '257949696'}, 'lfs': {'setstripe': {'size': 1441792, 'count': 38}}}
# 0.0012060556892386693
# {'loss': 0.0012060556892386693, 'hyperparameters': {'cb_buffer_size': 257949696.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 38.0, 'setstripe-size': 1441792.0}, 'iteration': 28, 'iteration_time': 0.040560375000495696, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '81788928'}, 'lfs': {'setstripe': {'size': 196608, 'count': 26}}}
# 0.0011266888900732202
# {'loss': 0.0011266888900732202, 'hyperparameters': {'cb_buffer_size': 81788928.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 26.0, 'setstripe-size': 196608.0}, 'iteration': 29, 'iteration_time': 0.04929893799999263, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '333447168'}, 'lfs': {'setstripe': {'size': 10747904, 'count': 47}}}
# 0.0011609451641184899
# {'loss': 0.0011609451641184899, 'hyperparameters': {'cb_buffer_size': 333447168.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 47.0, 'setstripe-size': 10747904.0}, 'iteration': 30, 'iteration_time': 0.04751614700217033, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '246415360'}, 'lfs': {'setstripe': {'size': 524288, 'count': 93}}}
# 0.0010612325480229752
# {'loss': 0.0010612325480229752, 'hyperparameters': {'cb_buffer_size': 246415360.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 93.0, 'setstripe-size': 524288.0}, 'iteration': 31, 'iteration_time': 0.039105777999793645, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '342884352'}, 'lfs': {'setstripe': {'size': 10682368, 'count': 23}}}
# 0.0011609451641184899
# {'loss': 0.0011609451641184899, 'hyperparameters': {'cb_buffer_size': 342884352.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 23.0, 'setstripe-size': 10682368.0}, 'iteration': 32, 'iteration_time': 0.03859674900013488, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '176160768'}, 'lfs': {'setstripe': {'size': 1310720, 'count': 145}}}
# 0.0014502238800817805
# {'loss': 0.0014502238800817805, 'hyperparameters': {'cb_buffer_size': 176160768.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 145.0, 'setstripe-size': 1310720.0}, 'iteration': 33, 'iteration_time': 0.04034797200074536, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '460324864'}, 'lfs': {'setstripe': {'size': 2359296, 'count': 12}}}
# 0.0011074125263064547
# {'loss': 0.0011074125263064547, 'hyperparameters': {'cb_buffer_size': 460324864.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 12.0, 'setstripe-size': 2359296.0}, 'iteration': 34, 'iteration_time': 0.03774254900054075, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '284164096'}, 'lfs': {'setstripe': {'size': 12648448, 'count': 52}}}
# 0.0011852843875894417
# {'loss': 0.0011852843875894417, 'hyperparameters': {'cb_buffer_size': 284164096.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 52.0, 'setstripe-size': 12648448.0}, 'iteration': 35, 'iteration_time': 0.042459021002287045, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '143654912'}, 'lfs': {'setstripe': {'size': 6029312, 'count': 29}}}
# 0.0012119713834500957
# {'loss': 0.0012119713834500957, 'hyperparameters': {'cb_buffer_size': 143654912.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 29.0, 'setstripe-size': 6029312.0}, 'iteration': 36, 'iteration_time': 0.06506432600144763, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '358612992'}, 'lfs': {'setstripe': {'size': 7864320, 'count': 5}}}
# 0.001119821670586111
# {'loss': 0.001119821670586111, 'hyperparameters': {'cb_buffer_size': 358612992.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 5.0, 'setstripe-size': 7864320.0}, 'iteration': 37, 'iteration_time': 0.05340920800153981, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '186646528'}, 'lfs': {'setstripe': {'size': 12255232, 'count': 21}}}
# 0.0012027582099956812
# {'loss': 0.0012027582099956812, 'hyperparameters': {'cb_buffer_size': 186646528.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 21.0, 'setstripe-size': 12255232.0}, 'iteration': 38, 'iteration_time': 0.05138493200138328, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '236978176'}, 'lfs': {'setstripe': {'size': 2490368, 'count': 88}}}
# 0.001185029941462385
# {'loss': 0.001185029941462385, 'hyperparameters': {'cb_buffer_size': 236978176.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 88.0, 'setstripe-size': 2490368.0}, 'iteration': 39, 'iteration_time': 0.03648633500051801, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '275775488'}, 'lfs': {'setstripe': {'size': 6881280, 'count': 33}}}
# 0.0012027582099956812
# {'loss': 0.0012027582099956812, 'hyperparameters': {'cb_buffer_size': 275775488.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 33.0, 'setstripe-size': 6881280.0}, 'iteration': 40, 'iteration_time': 0.06043944799966994, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '63963136'}, 'lfs': {'setstripe': {'size': 15990784, 'count': 14}}}
# 0.0013394025009156071
# {'loss': 0.0013394025009156071, 'hyperparameters': {'cb_buffer_size': 63963136.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 14.0, 'setstripe-size': 15990784.0}, 'iteration': 41, 'iteration_time': 0.03188660500018159, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '463470592'}, 'lfs': {'setstripe': {'size': 5767168, 'count': 9}}}
# 0.0011143141142940507
# {'loss': 0.0011143141142940507, 'hyperparameters': {'cb_buffer_size': 463470592.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 9.0, 'setstripe-size': 5767168.0}, 'iteration': 42, 'iteration_time': 0.0518189930007793, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '113246208'}, 'lfs': {'setstripe': {'size': 20709376, 'count': 69}}}
# 0.0012601711091467086
# {'loss': 0.0012601711091467086, 'hyperparameters': {'cb_buffer_size': 113246208.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 69.0, 'setstripe-size': 20709376.0}, 'iteration': 43, 'iteration_time': 0.054676833999110386, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '192937984'}, 'lfs': {'setstripe': {'size': 9175040, 'count': 1}}}
# 0.0017827024546215506
# {'loss': 0.0017827024546215506, 'hyperparameters': {'cb_buffer_size': 192937984.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 1.0, 'setstripe-size': 9175040.0}, 'iteration': 44, 'iteration_time': 0.051885486998799024, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '369098752'}, 'lfs': {'setstripe': {'size': 2621440, 'count': 2}}}
# 0.001366969367838408
# {'loss': 0.001366969367838408, 'hyperparameters': {'cb_buffer_size': 369098752.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 2621440.0}, 'iteration': 45, 'iteration_time': 0.04625925900108996, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '161480704'}, 'lfs': {'setstripe': {'size': 3670016, 'count': 5}}}
# 0.001171501900615968
# {'loss': 0.001171501900615968, 'hyperparameters': {'cb_buffer_size': 161480704.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 5.0, 'setstripe-size': 3670016.0}, 'iteration': 46, 'iteration_time': 0.06623559099898557, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '234881024'}, 'lfs': {'setstripe': {'size': 196608, 'count': 142}}}
# 0.0011710252167100668
# {'loss': 0.0011710252167100668, 'hyperparameters': {'cb_buffer_size': 234881024.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 142.0, 'setstripe-size': 196608.0}, 'iteration': 47, 'iteration_time': 0.118588286000886, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '6291456'}, 'lfs': {'setstripe': {'size': 14548992, 'count': 46}}}
# 0.003447267734182077
# {'loss': 0.003447267734182077, 'hyperparameters': {'cb_buffer_size': 6291456.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 46.0, 'setstripe-size': 14548992.0}, 'iteration': 48, 'iteration_time': 0.04494798900122987, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '326107136'}, 'lfs': {'setstripe': {'size': 29294592, 'count': 9}}}
# 0.0011201717122594466
# {'loss': 0.0011201717122594466, 'hyperparameters': {'cb_buffer_size': 326107136.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 9.0, 'setstripe-size': 29294592.0}, 'iteration': 49, 'iteration_time': 0.06966793299943674, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '439353344'}, 'lfs': {'setstripe': {'size': 5505024, 'count': 7}}}
# 0.0011143141142940507
# {'loss': 0.0011143141142940507, 'hyperparameters': {'cb_buffer_size': 439353344.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 5505024.0}, 'iteration': 50, 'iteration_time': 0.041609152998717036, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '213909504'}, 'lfs': {'setstripe': {'size': 11534336, 'count': 84}}}
# 0.0012071817588823902
# {'loss': 0.0012071817588823902, 'hyperparameters': {'cb_buffer_size': 213909504.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 84.0, 'setstripe-size': 11534336.0}, 'iteration': 51, 'iteration_time': 0.04159001399966655, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '256901120'}, 'lfs': {'setstripe': {'size': 9109504, 'count': 63}}}
# 0.0012200274535962886
# {'loss': 0.0012200274535962886, 'hyperparameters': {'cb_buffer_size': 256901120.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 63.0, 'setstripe-size': 9109504.0}, 'iteration': 52, 'iteration_time': 0.04690279700298561, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '283115520'}, 'lfs': {'setstripe': {'size': 25362432, 'count': 109}}}
# 0.0011472453402786118
# {'loss': 0.0011472453402786118, 'hyperparameters': {'cb_buffer_size': 283115520.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 109.0, 'setstripe-size': 25362432.0}, 'iteration': 53, 'iteration_time': 0.04722320099972421, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '393216000'}, 'lfs': {'setstripe': {'size': 4653056, 'count': 4}}}
# 0.0011809294312495667
# {'loss': 0.0011809294312495667, 'hyperparameters': {'cb_buffer_size': 393216000.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 4.0, 'setstripe-size': 4653056.0}, 'iteration': 54, 'iteration_time': 0.07023569900047733, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '89128960'}, 'lfs': {'setstripe': {'size': 32374784, 'count': 14}}}
# 0.001219879751306546
# {'loss': 0.001219879751306546, 'hyperparameters': {'cb_buffer_size': 89128960.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 14.0, 'setstripe-size': 32374784.0}, 'iteration': 55, 'iteration_time': 0.04613976299879141, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '352321536'}, 'lfs': {'setstripe': {'size': 8192000, 'count': 20}}}
# 0.0011728208503266131
# {'loss': 0.0011728208503266131, 'hyperparameters': {'cb_buffer_size': 352321536.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 20.0, 'setstripe-size': 8192000.0}, 'iteration': 56, 'iteration_time': 0.05728736499804654, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '159383552'}, 'lfs': {'setstripe': {'size': 29491200, 'count': 33}}}
# 0.001172146664565235
# {'loss': 0.001172146664565235, 'hyperparameters': {'cb_buffer_size': 159383552.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 33.0, 'setstripe-size': 29491200.0}, 'iteration': 57, 'iteration_time': 0.05762743699960993, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '207618048'}, 'lfs': {'setstripe': {'size': 17104896, 'count': 53}}}
# 0.001167666055490222
# {'loss': 0.001167666055490222, 'hyperparameters': {'cb_buffer_size': 207618048.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 53.0, 'setstripe-size': 17104896.0}, 'iteration': 58, 'iteration_time': 0.07171709500107681, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '131072000'}, 'lfs': {'setstripe': {'size': 13500416, 'count': 72}}}
# 0.0012295081352104746
# {'loss': 0.0012295081352104746, 'hyperparameters': {'cb_buffer_size': 131072000.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 72.0, 'setstripe-size': 13500416.0}, 'iteration': 59, 'iteration_time': 0.0428052179995575, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '320864256'}, 'lfs': {'setstripe': {'size': 3342336, 'count': 15}}}
# 0.0011305672709607613
# {'loss': 0.0011305672709607613, 'hyperparameters': {'cb_buffer_size': 320864256.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 15.0, 'setstripe-size': 3342336.0}, 'iteration': 60, 'iteration_time': 0.06735009899784927, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '485490688'}, 'lfs': {'setstripe': {'size': 20840448, 'count': 11}}}
# 0.001109333391111114
# {'loss': 0.001109333391111114, 'hyperparameters': {'cb_buffer_size': 485490688.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 11.0, 'setstripe-size': 20840448.0}, 'iteration': 61, 'iteration_time': 0.05020309700194048, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '291504128'}, 'lfs': {'setstripe': {'size': 1376256, 'count': 121}}}
# 0.0013876258901653117
# {'loss': 0.0013876258901653117, 'hyperparameters': {'cb_buffer_size': 291504128.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 121.0, 'setstripe-size': 1376256.0}, 'iteration': 62, 'iteration_time': 0.03757544900145149, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '382730240'}, 'lfs': {'setstripe': {'size': 18612224, 'count': 2}}}
# 0.001403861974251163
# {'loss': 0.001403861974251163, 'hyperparameters': {'cb_buffer_size': 382730240.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 18612224.0}, 'iteration': 63, 'iteration_time': 0.044608942000195384, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '48234496'}, 'lfs': {'setstripe': {'size': 7077888, 'count': 32}}}
# 0.0017910532604406139
# {'loss': 0.0017910532604406139, 'hyperparameters': {'cb_buffer_size': 48234496.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 32.0, 'setstripe-size': 7077888.0}, 'iteration': 64, 'iteration_time': 0.046881080997991376, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '266338304'}, 'lfs': {'setstripe': {'size': 24117248, 'count': 43}}}
# 0.0011635268698080613
# {'loss': 0.0011635268698080613, 'hyperparameters': {'cb_buffer_size': 266338304.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 43.0, 'setstripe-size': 24117248.0}, 'iteration': 65, 'iteration_time': 0.04667409600006067, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '224395264'}, 'lfs': {'setstripe': {'size': 9895936, 'count': 26}}}
# 0.0012027582099956812
# {'loss': 0.0012027582099956812, 'hyperparameters': {'cb_buffer_size': 224395264.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 26.0, 'setstripe-size': 9895936.0}, 'iteration': 66, 'iteration_time': 0.05387571100072819, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '246415360'}, 'lfs': {'setstripe': {'size': 0, 'count': 88}}}
# 0.0009303334470887048
# {'loss': 0.0009303334470887048, 'hyperparameters': {'cb_buffer_size': 246415360.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 88.0, 'setstripe-size': 0.0}, 'iteration': 67, 'iteration_time': 0.05190259599839919, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '299892736'}, 'lfs': {'setstripe': {'size': 851968, 'count': 89}}}
# 0.0011601296903769353
# {'loss': 0.0011601296903769353, 'hyperparameters': {'cb_buffer_size': 299892736.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 89.0, 'setstripe-size': 851968.0}, 'iteration': 68, 'iteration_time': 0.04988760199921671, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '175112192'}, 'lfs': {'setstripe': {'size': 4587520, 'count': 60}}}
# 0.0012198362468116477
# {'loss': 0.0012198362468116477, 'hyperparameters': {'cb_buffer_size': 175112192.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 60.0, 'setstripe-size': 4587520.0}, 'iteration': 69, 'iteration_time': 0.08368321500165621, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '196083712'}, 'lfs': {'setstripe': {'size': 2031616, 'count': 99}}}
# 0.0012202657965917315
# {'loss': 0.0012202657965917315, 'hyperparameters': {'cb_buffer_size': 196083712.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 99.0, 'setstripe-size': 2031616.0}, 'iteration': 70, 'iteration_time': 0.06047155700071016, 'status': 'ok'}
# ...
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '385875968'}, 'lfs': {'setstripe': {'size': 0, 'count': 6}}}
# 0.000883285641443607
# {'loss': 0.000883285641443607, 'hyperparameters': {'cb_buffer_size': 385875968.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 6.0, 'setstripe-size': 0.0}, 'iteration': 979, 'iteration_time': 0.05054956700041657, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '337641472'}, 'lfs': {'setstripe': {'size': 31129600, 'count': 5}}}
# 0.001139759455380859
# {'loss': 0.001139759455380859, 'hyperparameters': {'cb_buffer_size': 337641472.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 5.0, 'setstripe-size': 31129600.0}, 'iteration': 980, 'iteration_time': 0.05454118800116703, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '486539264'}, 'lfs': {'setstripe': {'size': 0, 'count': 9}}}
# 0.0008855870597915044
# {'loss': 0.0008855870597915044, 'hyperparameters': {'cb_buffer_size': 486539264.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 9.0, 'setstripe-size': 0.0}, 'iteration': 981, 'iteration_time': 0.0458831089999876, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '208666624'}, 'lfs': {'setstripe': {'size': 0, 'count': 1}}}
# 0.001319569455027641
# {'loss': 0.001319569455027641, 'hyperparameters': {'cb_buffer_size': 208666624.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 1.0, 'setstripe-size': 0.0}, 'iteration': 982, 'iteration_time': 0.044923460998688824, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '444596224'}, 'lfs': {'setstripe': {'size': 2162688, 'count': 74}}}
# 0.0011681597469861815
# {'loss': 0.0011681597469861815, 'hyperparameters': {'cb_buffer_size': 444596224.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 74.0, 'setstripe-size': 2162688.0}, 'iteration': 983, 'iteration_time': 0.04226754499904928, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '159383552'}, 'lfs': {'setstripe': {'size': 7667712, 'count': 115}}}
# 0.0012082997745721483
# {'loss': 0.0012082997745721483, 'hyperparameters': {'cb_buffer_size': 159383552.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 115.0, 'setstripe-size': 7667712.0}, 'iteration': 984, 'iteration_time': 0.03491964099885081, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '477102080'}, 'lfs': {'setstripe': {'size': 3276800, 'count': 8}}}
# 0.0011074125263064547
# {'loss': 0.0011074125263064547, 'hyperparameters': {'cb_buffer_size': 477102080.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 8.0, 'setstripe-size': 3276800.0}, 'iteration': 985, 'iteration_time': 0.06141782399936346, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '505413632'}, 'lfs': {'setstripe': {'size': 1179648, 'count': 11}}}
# 0.0011074125263064547
# {'loss': 0.0011074125263064547, 'hyperparameters': {'cb_buffer_size': 505413632.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 11.0, 'setstripe-size': 1179648.0}, 'iteration': 986, 'iteration_time': 0.029078135998133803, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '369098752'}, 'lfs': {'setstripe': {'size': 27918336, 'count': 6}}}
# 0.001109333391111114
# {'loss': 0.001109333391111114, 'hyperparameters': {'cb_buffer_size': 369098752.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 6.0, 'setstripe-size': 27918336.0}, 'iteration': 987, 'iteration_time': 0.049021288999938406, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '502267904'}, 'lfs': {'setstripe': {'size': 4587520, 'count': 15}}}
# 0.0011305672709607613
# {'loss': 0.0011305672709607613, 'hyperparameters': {'cb_buffer_size': 502267904.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 15.0, 'setstripe-size': 4587520.0}, 'iteration': 988, 'iteration_time': 0.04924511799981701, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '448790528'}, 'lfs': {'setstripe': {'size': 9109504, 'count': 9}}}
# 0.0011143141142940507
# {'loss': 0.0011143141142940507, 'hyperparameters': {'cb_buffer_size': 448790528.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 9.0, 'setstripe-size': 9109504.0}, 'iteration': 989, 'iteration_time': 0.04438148199915304, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '442499072'}, 'lfs': {'setstripe': {'size': 2555904, 'count': 13}}}
# 0.001141826583833132
# {'loss': 0.001141826583833132, 'hyperparameters': {'cb_buffer_size': 442499072.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 13.0, 'setstripe-size': 2555904.0}, 'iteration': 990, 'iteration_time': 0.03745517000061227, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '490733568'}, 'lfs': {'setstripe': {'size': 0, 'count': 7}}}
# 0.0008855870597915044
# {'loss': 0.0008855870597915044, 'hyperparameters': {'cb_buffer_size': 490733568.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 0.0}, 'iteration': 991, 'iteration_time': 0.05792979699981515, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '397410304'}, 'lfs': {'setstripe': {'size': 1769472, 'count': 4}}}
# 0.0011809294312495667
# {'loss': 0.0011809294312495667, 'hyperparameters': {'cb_buffer_size': 397410304.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 4.0, 'setstripe-size': 1769472.0}, 'iteration': 992, 'iteration_time': 0.042840218000492314, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '347078656'}, 'lfs': {'setstripe': {'size': 3997696, 'count': 10}}}
# 0.0011074125263064547
# {'loss': 0.0011074125263064547, 'hyperparameters': {'cb_buffer_size': 347078656.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 10.0, 'setstripe-size': 3997696.0}, 'iteration': 993, 'iteration_time': 0.043506550002348376, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '424673280'}, 'lfs': {'setstripe': {'size': 0, 'count': 7}}}
# 0.0008855870597915044
# {'loss': 0.0008855870597915044, 'hyperparameters': {'cb_buffer_size': 424673280.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 0.0}, 'iteration': 994, 'iteration_time': 0.04453448500134982, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '412090368'}, 'lfs': {'setstripe': {'size': 1048576, 'count': 3}}}
# 0.0011809294312495667
# {'loss': 0.0011809294312495667, 'hyperparameters': {'cb_buffer_size': 412090368.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 3.0, 'setstripe-size': 1048576.0}, 'iteration': 995, 'iteration_time': 0.07185066700185416, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '458227712'}, 'lfs': {'setstripe': {'size': 13303808, 'count': 12}}}
# 0.0011143141142940507
# {'loss': 0.0011143141142940507, 'hyperparameters': {'cb_buffer_size': 458227712.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 12.0, 'setstripe-size': 13303808.0}, 'iteration': 996, 'iteration_time': 0.06043222700100159, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '421527552'}, 'lfs': {'setstripe': {'size': 2883584, 'count': 9}}}
# 0.0011074125263064547
# {'loss': 0.0011074125263064547, 'hyperparameters': {'cb_buffer_size': 421527552.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 9.0, 'setstripe-size': 2883584.0}, 'iteration': 997, 'iteration_time': 0.070755343997007, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '435159040'}, 'lfs': {'setstripe': {'size': 1703936, 'count': 17}}}
# 0.0011305672709607613
# {'loss': 0.0011305672709607613, 'hyperparameters': {'cb_buffer_size': 435159040.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 17.0, 'setstripe-size': 1703936.0}, 'iteration': 998, 'iteration_time': 0.046055194001382915, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '520093696'}, 'lfs': {'setstripe': {'size': 5570560, 'count': 5}}}
# 0.0011562343288399873
# {'loss': 0.0011562343288399873, 'hyperparameters': {'cb_buffer_size': 520093696.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 5.0, 'setstripe-size': 5570560.0}, 'iteration': 999, 'iteration_time': 0.03675883599862573, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '333447168'}, 'lfs': {'setstripe': {'size': 6946816, 'count': 7}}}
# 0.001125250458197536
# {'loss': 0.001125250458197536, 'hyperparameters': {'cb_buffer_size': 333447168.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 7.0, 'setstripe-size': 6946816.0}, 'iteration': 1000, 'iteration_time': 0.03775065000081668, 'status': 'ok'}
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '470810624'}, 'lfs': {'setstripe': {'size': 655360, 'count': 19}}}
# 0.0011531763660220075
# {'loss': 0.0011531763660220075, 'hyperparameters': {'cb_buffer_size': 470810624.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 19.0, 'setstripe-size': 655360.0}, 'iteration': 1001, 'iteration_time': 0.052062470000237226, 'status': 'ok'}
# 100%|██████████| 1000/1000 [03:25<00:00,  3.19it/s, best loss: 0.0008714746208016269]

# %%
print(best)
d=  best
#print(bayes_trials.results)
bayes_trials_results = sorted(bayes_trials.results, key = lambda x: x['loss'])
#bayes_trials_results[:1]
# Out:
# {'cb_buffer_size': 367.0, 'romio_cb_read': 0, 'romio_cb_write': 1, 'romio_ds_read': 0, 'romio_ds_write': 0, 'setstripe-count': 6.0, 'setstripe-size': 1.0}

# %%
results = pd.read_csv(out_file)

# Sort with best scores on top and reset index for slicing
results.sort_values('train_time', ascending = True, inplace = True)
results.reset_index(inplace = True, drop = True)
results.head()
# Out:
#        loss                                             params  iteration  \
# 0  0.001204  {'cb_buffer_size': 448790528.0, 'romio_cb_read...        667
# 1  0.001107  {'cb_buffer_size': 505413632.0, 'romio_cb_read...        986
# 2  0.001107  {'cb_buffer_size': 381681664.0, 'romio_cb_read...        736
# 3  0.001214  {'cb_buffer_size': 284164096.0, 'romio_cb_read...        545
# 4  0.000886  {'cb_buffer_size': 328204288.0, 'romio_cb_read...        677
#
#    train_time  output
# 0    0.028086       0
# 1    0.029078       0
# 2    0.029614       0
# 3    0.029786       0
# 4    0.030123       0

# %%
import ast

# Convert from a string to a dictionary
ast.literal_eval(results.loc[0, 'params'])
best_bayes_params = ast.literal_eval(results.loc[0, 'params']).copy()
print(best_bayes_params)
log = open('best.txt','a')
print(results.loc[0,'output'])
print(results.loc[0,'output'],file=log)
log.close()
# Out:
# {'cb_buffer_size': 448790528.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 4.0, 'setstripe-size': 29491200.0}
# 0

# %%
bayes_params = pd.DataFrame(columns = list(ast.literal_eval(results.loc[0, 'params']).keys()),
                            index = list(range(len(results))))

# Add the results with each parameter a different column
for i, params in enumerate(results['params']):
    bayes_params.loc[i, :] = list(ast.literal_eval(params).values())
bayes_params['train_time'] = results['train_time']    
bayes_params['loss'] = results['loss']
bayes_params['iteration'] = results['iteration']
bayes_params['output']=results['output']

bayes_params.head()
# Out:
#   cb_buffer_size romio_cb_read romio_cb_write romio_ds_read romio_ds_write  \
# 0    4.48791e+08       disable        disable       disable         enable
# 1    5.05414e+08       disable        disable        enable         enable
# 2    3.81682e+08        enable        disable        enable         enable
# 3    2.84164e+08       disable        disable       disable         enable
# 4    3.28204e+08       disable        disable        enable         enable
#
#   setstripe-count setstripe-size  train_time      loss  iteration  output
# 0               4    2.94912e+07    0.028086  0.001204        667       0
# 1              11    1.17965e+06    0.029078  0.001107        986       0
# 2              10    2.68698e+06    0.029614  0.001107        736       0
# 3               4    2.75251e+06    0.029786  0.001214        545       0
# 4               7              0    0.030123  0.000886        677       0

# %%
#os.chdir('./plots')
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

# Density plots of the learning rate distributions 
sns.kdeplot(bayes_params['loss'], label = 'Loss Variation', linewidth = 2)
plt.legend()
plt.xlabel('Loss'); plt.ylabel('Density'); plt.title('Loss Distribution');
#plt.savefig(file_suffix+'_loss.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18


sns.kdeplot(bayes_params['cb_buffer_size'], label = 'bayes cb_buffer_size', linewidth = 2)
sns.kdeplot(cb_buffer_size_dist,color="red",linewidth=2, label = 'initial cb_buffer_size')

plt.legend()
plt.xlabel('cb_buffer_size'); plt.ylabel('Density'); plt.title('cb_buffer_size Distribution');
#plt.savefig(file_suffix+'_cb_buffer_size.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-size'], label = 'bayes setstripe-size', linewidth = 2)
sns.kdeplot(setstripe_size_dist,color="red",linewidth=2, label = 'initial setstripe-size')

plt.legend()
plt.xlabel('setstripe-size'); plt.ylabel('Density'); plt.title('setstripe-size Distribution');
#plt.savefig(file_suffix+'_setstripe-size.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-count'], label = 'bayes setstripe-count', linewidth = 2)
sns.kdeplot(setstripe_count_dist,color="red",linewidth=2, label = 'initial setstripe-count')

plt.legend()
plt.xlabel('setstripe-count'); plt.ylabel('Density'); plt.title('setstripe-count Distribution');
#plt.savefig(file_suffix+'_setstripe-count.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize = (20, 8))
from scipy.stats import itemfreq
plt.rcParams['font.size'] = 18
bayes_params['romio_ds_read'].value_counts().plot.bar()#plt.hist(romio_ds_read_dist,color="red",linewidth=2, label = 'initial romio_ds_read')

plt.legend()
plt.xlabel('romio_ds_read'); plt.ylabel('Count'); plt.title('romio_ds_read Distribution');
#plt.savefig(file_suffix+'_romio_ds_read.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

#plt.hist(bayes_params['romio_ds_write'], label = 'bayes romio_ds_write', linewidth = 2)
#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_ds_write')
bayes_params['romio_ds_write'].value_counts().plot.bar()
plt.legend()
plt.xlabel('romio_ds_write'); plt.ylabel('Count'); plt.title('romio_ds_write Distribution');
#plt.savefig(file_suffix+'_romio_ds_write.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_write'].value_counts().plot.bar()#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_cb_write')

plt.legend()
plt.xlabel('romio_cb_write'); plt.ylabel('Count'); plt.title('romio_cb_write Distribution');
#plt.savefig(file_suffix+'_romio_cb_write.png')

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_read'].value_counts().plot.bar()#plt.hist(romio_cb_read_dist,color="red",linewidth=2, label = 'initial romio_cb_read')

plt.legend()
plt.xlabel('romio_cb_read'); plt.ylabel('Count'); plt.title('romio_cb_read Distribution');
#plt.savefig(file_suffix+'_romio_cb_read.png')

# %%
os.chdir('../')
