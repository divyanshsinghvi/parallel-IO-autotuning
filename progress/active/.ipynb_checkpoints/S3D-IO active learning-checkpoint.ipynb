# %%
# Data manipulation
import pandas as pd
import numpy as np
# Evaluation of the model
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import roc_auc_score
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.size'] = 18
# %matplotlib inline
MAX_EVALS = 20
import csv
from hyperopt import STATUS_OK
from timeit import default_timer as timer
import json
import shlex
import subprocess
import logging
from pprint import pprint
import re
import os

# %%
file_suffix = "S3D-IO-200-200-400-2-2-4-1" + str(MAX_EVALS)
project_dir = "/home/dsinghvi/project/progress/"
def runthebenchmark(hyperparameters):
    os.chdir(project_dir+'active/../')
    storeinfile(hyperparameters)
    out=subprocess.Popen(["python3","read_config_general.py","-n 2","-c200 200 400 2 2 4 1"], shell=False, stdout=subprocess.PIPE)
    logging.basicConfig(level=logging.DEBUG)
    output=out.stdout.read().decode('utf-8')
    print("output"+output)
    if len(output.split(" ")) > 5:
        values = output.split(" ")
        value = float(float(values[6])*1024)/float(values[5]) + float(float(values[3])*1024)/float(values[2])
        value = float(value)
        print(value)
        return float((value/100)**3),output
    return 0,0;

# %%
def storeinfile(hyperparameters):
    data={"mpi": {"romio_ds_read": "enable", "romio_ds_write": "disable"}, "lfs": {"setstripe": {"size": "16777216", "count": 4}}}
    data["lfs"]["setstripe"]["size"] = int(hyperparameters["setstripe-size"])
    data["lfs"]["setstripe"]["count"] = int(hyperparameters["setstripe-count"])

    data["mpi"]["romio_ds_read"] = hyperparameters["romio_ds_read"]
    data["mpi"]["romio_ds_write"] = hyperparameters["romio_ds_write"]
    data["mpi"]["romio_cb_read"] = hyperparameters["romio_cb_read"]
    data["mpi"]["romio_cb_write"] = hyperparameters["romio_cb_write"]
    data["mpi"]["cb_buffer_size"] = str(int(hyperparameters["cb_buffer_size"]))
    with open("confex.json","w") as fp:
        json.dump(data,fp)
    print(data)

# %%
def objective(hyperparameters):
    global ITERATION
    ITERATION += 1
    start = timer()
    result=0
    while(result == 0):
        print("rerun")
        result,output = runthebenchmark(hyperparameters)
        print(result)
    run_time = timer() - start
    print({'loss': result, 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK})
    # Write to the csv file ('a' means append)
    of_connection = open(out_file, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([float(result), hyperparameters, ITERATION, run_time, output])
    return {'loss': float(result), 'hyperparameters': hyperparameters, 'iteration': ITERATION, 'iteration_time': run_time, 'status': STATUS_OK}

# %%
from hyperopt import hp
from hyperopt.pyll.stochastic import sample

space = {
    'romio_ds_read' : hp.choice('romio_ds_read',['enable','disable']),
    'romio_ds_write' : hp.choice('romio_ds_write',['enable','disable']),
    'romio_cb_read' : hp.choice('romio_cb_read',['enable','disable']),
    'romio_cb_write' : hp.choice('romio_cb_write',['enable','disable']),
    'cb_buffer_size' : 1048576*hp.quniform('cb_buffer_size',1,512,1),
    'setstripe-size' : 65536*(hp.quniform('setstripe-size',0,512,1)),
    'setstripe-count' : hp.qloguniform('setstripe-count',0,5,1)
    
}

# %%
x = sample(space)
params = x
print(x)

cb_buffer_size_dist = []
for _ in range(1000):
    cb_buffer_size_dist.append(sample(space)['cb_buffer_size'])
    
setstripe_size_dist = []
for _ in range(1000):
    setstripe_size_dist.append(sample(space)['setstripe-size'])
    
setstripe_count_dist = []
for _ in range(1000):
    setstripe_count_dist.append(sample(space)['setstripe-count']) 
    
romio_ds_read_dist = []
for _ in range(20):
    romio_ds_read_dist.append(sample(space)['romio_ds_read'])
    
romio_ds_write_dist = []
for _ in range(20):
    romio_ds_write_dist.append(sample(space)['romio_ds_write'])
    
romio_cb_read_dist = []
for _ in range(20):
    romio_cb_read_dist.append(sample(space)['romio_cb_read']) 
    
romio_cb_write_dist = []
for _ in range(20):
    romio_cb_write_dist.append(sample(space)['romio_cb_write'])
# Out:
# {'cb_buffer_size': 283115520.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 16.0, 'setstripe-size': 11730944.0}

# %%
# File to save first results
print(os.getcwd())
out_file = project_dir+'active/result/gbm_trials-'+file_suffix+'.csv'
of_connection = open(out_file, 'w')
writer = csv.writer(of_connection)
writer.writerow(['loss', 'params', 'iteration', 'train_time', 'output'])
of_connection.close()
# Out:
# /home/dsinghvi/project/progress/active

# %%
from hyperopt import tpe

# Create the algorithm
tpe_algorithm = tpe.suggest


from hyperopt import Trials

# Record results
bayes_trials = Trials()

from hyperopt import fmin


ITERATION = 20

best = fmin(fn = objective, space = space, algo = tpe.suggest, trials = bayes_trials, max_evals = MAX_EVALS)
# Out:
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '9437184'}, 'lfs': {'setstripe': {'size': 23855104, 'count': 27}}}
# outputS3D-IO 200-200-400-2-2-4-1 597.97 1.91 3.27 484.05 5.72 12.10 0.10 0.04 23855104 27 enable enable disable disable 9437184
#
# 15.371367661566158
# 0.0036319305156371426
# {'loss': 0.0036319305156371426, 'hyperparameters': {'cb_buffer_size': 9437184.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 27.0, 'setstripe-size': 23855104.0}, 'iteration': 21, 'iteration_time': 20.533481519669294, 'status': 'ok'}
#   5%|▌         | 1/20 [00:20<06:30, 20.55s/it, best loss: 0.0036319305156371426]
# INFO:hyperopt.tpe:tpe_transform took 0.012316 seconds
# INFO:hyperopt.tpe:TPE using 1/1 trials with best loss 0.003632
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '286261248'}, 'lfs': {'setstripe': {'size': 16580608, 'count': 16}}}
# outputS3D-IO 200-200-400-2-2-4-1 607.68 1.91 3.21 537.92 5.72 10.89 0.07 0.05 16580608 16 enable enable disable enable 286261248
#
# 14.107292764061613
# 0.0028075728733575733
# {'loss': 0.0028075728733575733, 'hyperparameters': {'cb_buffer_size': 286261248.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 16.0, 'setstripe-size': 16580608.0}, 'iteration': 22, 'iteration_time': 19.24692566227168, 'status': 'ok'}
#  10%|█         | 2/20 [00:39<06:03, 20.17s/it, best loss: 0.0028075728733575733]
# INFO:hyperopt.tpe:tpe_transform took 0.005271 seconds
# INFO:hyperopt.tpe:TPE using 2/2 trials with best loss 0.002808
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '255852544'}, 'lfs': {'setstripe': {'size': 24969216, 'count': 2}}}
# outputS3D-IO 200-200-400-2-2-4-1 783.92 1.91 2.49 716.89 5.72 8.17 0.04 0.05 24969216 2 disable enable enable disable 255852544
#
# 10.665351175842087
# 0.0012131806641357456
# {'loss': 0.0012131806641357456, 'hyperparameters': {'cb_buffer_size': 255852544.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 2.0, 'setstripe-size': 24969216.0}, 'iteration': 23, 'iteration_time': 15.830061494372785, 'status': 'ok'}
#  15%|█▌        | 3/20 [00:55<05:20, 18.87s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.005416 seconds
# INFO:hyperopt.tpe:TPE using 3/3 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '273678336'}, 'lfs': {'setstripe': {'size': 14876672, 'count': 2}}}
# outputS3D-IO 200-200-400-2-2-4-1 760.20 1.91 2.57 666.35 5.72 8.79 0.05 0.13 14876672 2 disable disable disable disable 273678336
#
# 11.36289192773039
# 0.0014671233473941166
# {'loss': 0.0014671233473941166, 'hyperparameters': {'cb_buffer_size': 273678336.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 14876672.0}, 'iteration': 24, 'iteration_time': 16.399805321358144, 'status': 'ok'}
#  20%|██        | 4/20 [01:12<04:50, 18.14s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.011627 seconds
# INFO:hyperopt.tpe:TPE using 4/4 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '301989888'}, 'lfs': {'setstripe': {'size': 196608, 'count': 87}}}
# outputS3D-IO 200-200-400-2-2-4-1 715.51 1.91 2.73 539.54 5.72 10.86 0.04 0.05 196608 87 disable enable enable enable 301989888
#
# 13.589553368594768
# 0.0025096638246157963
# {'loss': 0.0025096638246157963, 'hyperparameters': {'cb_buffer_size': 301989888.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 87.0, 'setstripe-size': 196608.0}, 'iteration': 25, 'iteration_time': 18.7470485214144, 'status': 'ok'}
#  25%|██▌       | 5/20 [01:30<04:34, 18.33s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009603 seconds
# INFO:hyperopt.tpe:TPE using 5/5 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '485490688'}, 'lfs': {'setstripe': {'size': 20185088, 'count': 2}}}
# outputS3D-IO 200-200-400-2-2-4-1 696.03 1.91 2.81 624.83 5.72 9.38 0.04 0.12 20185088 2 enable disable disable disable 485490688
#
# 12.184191603902017
# 0.0018087983775608965
# {'loss': 0.0018087983775608965, 'hyperparameters': {'cb_buffer_size': 485490688.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 2.0, 'setstripe-size': 20185088.0}, 'iteration': 26, 'iteration_time': 17.154609244316816, 'status': 'ok'}
#  30%|███       | 6/20 [01:48<04:11, 17.98s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.011800 seconds
# INFO:hyperopt.tpe:TPE using 6/6 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '490733568'}, 'lfs': {'setstripe': {'size': 14942208, 'count': 11}}}
# outputS3D-IO 200-200-400-2-2-4-1 616.87 1.91 3.17 516.78 5.72 11.34 0.05 0.09 14942208 11 disable disable disable disable 490733568
#
# 14.504771755111392
# 0.0030516357751248
# {'loss': 0.0030516357751248, 'hyperparameters': {'cb_buffer_size': 490733568.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 11.0, 'setstripe-size': 14942208.0}, 'iteration': 27, 'iteration_time': 19.46175007056445, 'status': 'ok'}
#  35%|███▌      | 7/20 [02:07<03:59, 18.44s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.012951 seconds
# INFO:hyperopt.tpe:TPE using 7/7 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '359661568'}, 'lfs': {'setstripe': {'size': 25624576, 'count': 1}}}
# outputS3D-IO 200-200-400-2-2-4-1 503.44 1.91 3.88 441.34 5.72 13.28 0.05 0.14 25624576 1 enable enable disable enable 359661568
#
# 17.156533533721763
# 0.005049968049344521
# {'loss': 0.005049968049344521, 'hyperparameters': {'cb_buffer_size': 359661568.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 1.0, 'setstripe-size': 25624576.0}, 'iteration': 28, 'iteration_time': 22.213023367337883, 'status': 'ok'}
#  40%|████      | 8/20 [02:29<03:54, 19.58s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.005073 seconds
# INFO:hyperopt.tpe:TPE using 8/8 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '256901120'}, 'lfs': {'setstripe': {'size': 6750208, 'count': 4}}}
# outputS3D-IO 200-200-400-2-2-4-1 645.86 1.91 3.02 630.41 5.72 9.29 0.06 0.09 6750208 4 enable enable enable enable 256901120
#
# 12.319495553232617
# 0.001869729478981878
# {'loss': 0.001869729478981878, 'hyperparameters': {'cb_buffer_size': 256901120.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'enable', 'setstripe-count': 4.0, 'setstripe-size': 6750208.0}, 'iteration': 29, 'iteration_time': 17.429274692200124, 'status': 'ok'}
#  45%|████▌     | 9/20 [02:47<03:28, 18.94s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009929 seconds
# INFO:hyperopt.tpe:TPE using 9/9 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '205520896'}, 'lfs': {'setstripe': {'size': 589824, 'count': 13}}}
# outputS3D-IO 200-200-400-2-2-4-1 110.06 1.91 17.75 222.57 5.72 26.33 0.05 0.08 589824 13 disable disable disable enable 205520896
#
# 44.08724510415232
# 0.08569172497448317
# {'loss': 0.08569172497448317, 'hyperparameters': {'cb_buffer_size': 205520896.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 13.0, 'setstripe-size': 589824.0}, 'iteration': 30, 'iteration_time': 49.20940839033574, 'status': 'ok'}
#  50%|█████     | 10/20 [03:36<04:40, 28.03s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009685 seconds
# INFO:hyperopt.tpe:TPE using 10/10 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '300941312'}, 'lfs': {'setstripe': {'size': 19005440, 'count': 5}}}
# outputS3D-IO 200-200-400-2-2-4-1 655.23 1.91 2.98 552.47 5.72 10.61 0.05 0.05 19005440 5 enable disable enable disable 300941312
#
# 13.586954549017465
# 0.0025082242814373737
# {'loss': 0.0025082242814373737, 'hyperparameters': {'cb_buffer_size': 300941312.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 5.0, 'setstripe-size': 19005440.0}, 'iteration': 31, 'iteration_time': 18.617940644733608, 'status': 'ok'}
#  55%|█████▌    | 11/20 [03:55<03:46, 25.21s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.011415 seconds
# INFO:hyperopt.tpe:TPE using 11/11 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '328204288'}, 'lfs': {'setstripe': {'size': 33357824, 'count': 9}}}
# outputS3D-IO 200-200-400-2-2-4-1 110.40 1.91 17.69 653.44 5.72 8.97 0.06 0.11 33357824 9 disable enable disable disable 328204288
#
# 26.67970304759471
# 0.018990787506936502
# {'loss': 0.018990787506936502, 'hyperparameters': {'cb_buffer_size': 328204288.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 9.0, 'setstripe-size': 33357824.0}, 'iteration': 32, 'iteration_time': 31.643427305854857, 'status': 'ok'}
#  60%|██████    | 12/20 [04:26<03:37, 27.15s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.005262 seconds
# INFO:hyperopt.tpe:TPE using 12/12 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'cb_buffer_size': '481296384'}, 'lfs': {'setstripe': {'size': 589824, 'count': 13}}}
# outputS3D-IO 200-200-400-2-2-4-1 669.55 1.91 2.92 677.98 5.72 8.64 0.04 0.11 589824 13 disable disable enable disable 481296384
#
# 11.560437023616625
# 0.0015449796257411281
# {'loss': 0.0015449796257411281, 'hyperparameters': {'cb_buffer_size': 481296384.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 13.0, 'setstripe-size': 589824.0}, 'iteration': 33, 'iteration_time': 16.48546184692532, 'status': 'ok'}
#  65%|██████▌   | 13/20 [04:43<02:47, 23.96s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009933 seconds
# INFO:hyperopt.tpe:TPE using 13/13 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'cb_buffer_size': '375390208'}, 'lfs': {'setstripe': {'size': 6225920, 'count': 105}}}
# outputS3D-IO 200-200-400-2-2-4-1 555.55 1.91 3.52 398.81 5.72 14.69 0.06 0.07 6225920 105 enable disable disable enable 375390208
#
# 18.20744071365891
# 0.006035965009275482
# {'loss': 0.006035965009275482, 'hyperparameters': {'cb_buffer_size': 375390208.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'enable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 105.0, 'setstripe-size': 6225920.0}, 'iteration': 34, 'iteration_time': 23.242601522244513, 'status': 'ok'}
#  70%|███████   | 14/20 [05:06<02:22, 23.75s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.011263 seconds
# INFO:hyperopt.tpe:TPE using 14/14 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '393216000'}, 'lfs': {'setstripe': {'size': 4325376, 'count': 22}}}
# outputS3D-IO 200-200-400-2-2-4-1 609.93 1.91 3.20 400.67 5.72 14.62 0.05 0.08 4325376 22 disable disable enable enable 393216000
#
# 17.825376714323873
# 0.0056639074792466
# {'loss': 0.0056639074792466, 'hyperparameters': {'cb_buffer_size': 393216000.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 22.0, 'setstripe-size': 4325376.0}, 'iteration': 35, 'iteration_time': 23.173270646482706, 'status': 'ok'}
#  75%|███████▌  | 15/20 [05:29<01:57, 23.59s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009783 seconds
# INFO:hyperopt.tpe:TPE using 15/15 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '124780544'}, 'lfs': {'setstripe': {'size': 1703936, 'count': 17}}}
# outputS3D-IO 200-200-400-2-2-4-1 616.39 1.91 3.17 318.03 5.72 18.42 0.10 0.06 1703936 17 disable disable disable disable 124780544
#
# 21.590438027714438
# 0.010064318222506226
# {'loss': 0.010064318222506226, 'hyperparameters': {'cb_buffer_size': 124780544.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 17.0, 'setstripe-size': 1703936.0}, 'iteration': 36, 'iteration_time': 26.69305409491062, 'status': 'ok'}
#  80%|████████  | 16/20 [05:56<01:38, 24.53s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.008216 seconds
# INFO:hyperopt.tpe:TPE using 16/16 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '145752064'}, 'lfs': {'setstripe': {'size': 26279936, 'count': 45}}}
# outputS3D-IO 200-200-400-2-2-4-1 572.59 1.91 3.41 651.96 5.72 8.99 0.08 0.03 26279936 45 enable disable disable disable 145752064
#
# 12.399886886936475
# 0.0019065718236820134
# {'loss': 0.0019065718236820134, 'hyperparameters': {'cb_buffer_size': 145752064.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'enable', 'romio_ds_write': 'disable', 'setstripe-count': 45.0, 'setstripe-size': 26279936.0}, 'iteration': 37, 'iteration_time': 17.473209365271032, 'status': 'ok'}
#  85%|████████▌ | 17/20 [06:13<01:07, 22.42s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.010393 seconds
# INFO:hyperopt.tpe:TPE using 17/17 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '378535936'}, 'lfs': {'setstripe': {'size': 12451840, 'count': 84}}}
# outputS3D-IO 200-200-400-2-2-4-1 624.51 1.91 3.13 493.94 5.72 11.86 0.05 0.07 12451840 84 disable enable disable disable 378535936
#
# 14.990081713150854
# 0.003368309582159772
# {'loss': 0.003368309582159772, 'hyperparameters': {'cb_buffer_size': 378535936.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 84.0, 'setstripe-size': 12451840.0}, 'iteration': 38, 'iteration_time': 20.102875134907663, 'status': 'ok'}
#  90%|█████████ | 18/20 [06:34<00:43, 21.73s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.015083 seconds
# INFO:hyperopt.tpe:TPE using 18/18 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'cb_buffer_size': '10485760'}, 'lfs': {'setstripe': {'size': 6291456, 'count': 5}}}
# outputS3D-IO 200-200-400-2-2-4-1 118.24 1.91 16.52 501.32 5.72 11.69 0.04 0.04 6291456 5 disable disable enable enable 10485760
#
# 28.224986981594572
# 0.022485432777276895
# {'loss': 0.022485432777276895, 'hyperparameters': {'cb_buffer_size': 10485760.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'enable', 'romio_ds_read': 'disable', 'romio_ds_write': 'disable', 'setstripe-count': 5.0, 'setstripe-size': 6291456.0}, 'iteration': 39, 'iteration_time': 33.0483120335266, 'status': 'ok'}
#  95%|█████████▌| 19/20 [07:07<00:25, 25.14s/it, best loss: 0.0012131806641357456]
# INFO:hyperopt.tpe:tpe_transform took 0.009805 seconds
# INFO:hyperopt.tpe:TPE using 19/19 trials with best loss 0.001213
# rerun
# {'mpi': {'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'cb_buffer_size': '5242880'}, 'lfs': {'setstripe': {'size': 29425664, 'count': 85}}}
# outputS3D-IO 200-200-400-2-2-4-1 518.26 1.91 3.77 442.18 5.72 13.25 0.07 0.03 29425664 85 disable enable disable disable 5242880
#
# 17.020228937427586
# 0.004930559366732981
# {'loss': 0.004930559366732981, 'hyperparameters': {'cb_buffer_size': 5242880.0, 'romio_cb_read': 'disable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 85.0, 'setstripe-size': 29425664.0}, 'iteration': 40, 'iteration_time': 22.085261955857277, 'status': 'ok'}
# 100%|██████████| 20/20 [07:29<00:00, 24.23s/it, best loss: 0.0012131806641357456]

# %%
print(best)
d=  best
#print(bayes_trials.results)
bayes_trials_results = sorted(bayes_trials.results, key = lambda x: x['loss'])
#bayes_trials_results[:1]
# Out:
# {'cb_buffer_size': 244.0, 'romio_cb_read': 0, 'romio_cb_write': 1, 'romio_ds_read': 1, 'romio_ds_write': 0, 'setstripe-count': 2.0, 'setstripe-size': 381.0}

# %%
results = pd.read_csv(out_file)

# Sort with best scores on top and reset index for slicing
results.sort_values('train_time', ascending = True, inplace = True)
results.reset_index(inplace = True, drop = True)
results.head()
# Out:
#        loss                                             params  iteration  \
# 0  0.001213  {'cb_buffer_size': 255852544.0, 'romio_cb_read...         23
# 1  0.001467  {'cb_buffer_size': 273678336.0, 'romio_cb_read...         24
# 2  0.001545  {'cb_buffer_size': 481296384.0, 'romio_cb_read...         33
# 3  0.001809  {'cb_buffer_size': 485490688.0, 'romio_cb_read...         26
# 4  0.001870  {'cb_buffer_size': 256901120.0, 'romio_cb_read...         29
#
#    train_time                                             output
# 0   15.830061  S3D-IO 200-200-400-2-2-4-1 783.92 1.91 2.49 71...
# 1   16.399805  S3D-IO 200-200-400-2-2-4-1 760.20 1.91 2.57 66...
# 2   16.485462  S3D-IO 200-200-400-2-2-4-1 669.55 1.91 2.92 67...
# 3   17.154609  S3D-IO 200-200-400-2-2-4-1 696.03 1.91 2.81 62...
# 4   17.429275  S3D-IO 200-200-400-2-2-4-1 645.86 1.91 3.02 63...

# %%
import ast

# Convert from a string to a dictionary
ast.literal_eval(results.loc[0, 'params'])
best_bayes_params = ast.literal_eval(results.loc[0, 'params']).copy()
print(best_bayes_params)
log = open('best.txt','a')
print(results.loc[0,'output'])
print(results.loc[0,'output'],file=log)
log.close()
# Out:
# {'cb_buffer_size': 255852544.0, 'romio_cb_read': 'enable', 'romio_cb_write': 'disable', 'romio_ds_read': 'disable', 'romio_ds_write': 'enable', 'setstripe-count': 2.0, 'setstripe-size': 24969216.0}
# S3D-IO 200-200-400-2-2-4-1 783.92 1.91 2.49 716.89 5.72 8.17 0.04 0.05 24969216 2 disable enable enable disable 255852544

# %%
bayes_params = pd.DataFrame(columns = list(ast.literal_eval(results.loc[0, 'params']).keys()),
                            index = list(range(len(results))))

# Add the results with each parameter a different column
for i, params in enumerate(results['params']):
    bayes_params.loc[i, :] = list(ast.literal_eval(params).values())
bayes_params['train_time'] = results['train_time']    
bayes_params['loss'] = results['loss']
bayes_params['iteration'] = results['iteration']
bayes_params['output']=results['output']

bayes_params.head()
# Out:
#   cb_buffer_size romio_cb_read romio_cb_write romio_ds_read romio_ds_write  \
# 0    2.55853e+08        enable        disable       disable         enable
# 1    2.73678e+08       disable        disable       disable        disable
# 2    4.81296e+08        enable        disable       disable        disable
# 3    4.85491e+08       disable        disable        enable        disable
# 4    2.56901e+08        enable         enable        enable         enable
#
#   setstripe-count setstripe-size  train_time      loss  iteration  \
# 0               2    2.49692e+07   15.830061  0.001213         23
# 1               2    1.48767e+07   16.399805  0.001467         24
# 2              13         589824   16.485462  0.001545         33
# 3               2    2.01851e+07   17.154609  0.001809         26
# 4               4    6.75021e+06   17.429275  0.001870         29
#
#                                               output
# 0  S3D-IO 200-200-400-2-2-4-1 783.92 1.91 2.49 71...
# 1  S3D-IO 200-200-400-2-2-4-1 760.20 1.91 2.57 66...
# 2  S3D-IO 200-200-400-2-2-4-1 669.55 1.91 2.92 67...
# 3  S3D-IO 200-200-400-2-2-4-1 696.03 1.91 2.81 62...
# 4  S3D-IO 200-200-400-2-2-4-1 645.86 1.91 3.02 63...

# %%
os.chdir('./plots')
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

# Density plots of the learning rate distributions 
sns.kdeplot(bayes_params['loss'], label = 'Loss Variation', linewidth = 2)
plt.legend()
plt.xlabel('Loss'); plt.ylabel('Density'); plt.title('Loss Distribution');
plt.savefig(file_suffix+'_loss.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=18.0 to DejaVu Sans ('/home/dsinghvi/project/progress/env/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# DEBUG:matplotlib.font_manager:findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=21.599999999999998 to DejaVu Sans ('/home/dsinghvi/project/progress/env/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18


sns.kdeplot(bayes_params['cb_buffer_size'], label = 'bayes cb_buffer_size', linewidth = 2)
sns.kdeplot(cb_buffer_size_dist,color="red",linewidth=2, label = 'initial cb_buffer_size')

plt.legend()
plt.xlabel('cb_buffer_size'); plt.ylabel('Density'); plt.title('cb_buffer_size Distribution');
plt.savefig(file_suffix+'_cb_buffer_size.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-size'], label = 'bayes setstripe-size', linewidth = 2)
sns.kdeplot(setstripe_size_dist,color="red",linewidth=2, label = 'initial setstripe-size')

plt.legend()
plt.xlabel('setstripe-size'); plt.ylabel('Density'); plt.title('setstripe-size Distribution');
plt.savefig(file_suffix+'_setstripe-size.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

sns.kdeplot(bayes_params['setstripe-count'], label = 'bayes setstripe-count', linewidth = 2)
sns.kdeplot(setstripe_count_dist,color="red",linewidth=2, label = 'initial setstripe-count')

plt.legend()
plt.xlabel('setstripe-count'); plt.ylabel('Density'); plt.title('setstripe-count Distribution');
plt.savefig(file_suffix+'_setstripe-count.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
from scipy.stats import itemfreq
plt.rcParams['font.size'] = 18
bayes_params['romio_ds_read'].value_counts().plot.bar()#plt.hist(romio_ds_read_dist,color="red",linewidth=2, label = 'initial romio_ds_read')

plt.legend()
plt.xlabel('romio_ds_read'); plt.ylabel('Count'); plt.title('romio_ds_read Distribution');
plt.savefig(file_suffix+'_romio_ds_read.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

#plt.hist(bayes_params['romio_ds_write'], label = 'bayes romio_ds_write', linewidth = 2)
#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_ds_write')
bayes_params['romio_ds_write'].value_counts().plot.bar()
plt.legend()
plt.xlabel('romio_ds_write'); plt.ylabel('Count'); plt.title('romio_ds_write Distribution');
plt.savefig(file_suffix+'_romio_ds_write.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_write'].value_counts().plot.bar()#plt.hist(romio_ds_write_dist,color="red",linewidth=2, label = 'initial romio_cb_write')

plt.legend()
plt.xlabel('romio_cb_write'); plt.ylabel('Count'); plt.title('romio_cb_write Distribution');
plt.savefig(file_suffix+'_romio_cb_write.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
plt.figure(figsize = (20, 8))
plt.rcParams['font.size'] = 18

bayes_params['romio_cb_read'].value_counts().plot.bar()#plt.hist(romio_cb_read_dist,color="red",linewidth=2, label = 'initial romio_cb_read')

plt.legend()
plt.xlabel('romio_cb_read'); plt.ylabel('Count'); plt.title('romio_cb_read Distribution');
plt.savefig(file_suffix+'_romio_cb_read.png')
# Out:
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos
# DEBUG:matplotlib.axes._base:update_title_pos

# %%
os.chdir('../')
